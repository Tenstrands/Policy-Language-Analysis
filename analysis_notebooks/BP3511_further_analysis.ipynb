# %% [markdown]
# # BP3511 Preliminary Analysis

# %%
# Import modules 
import os 
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import matplotlib.pyplot as plt
from collections import Counter
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.

# %%
# Change the working directory
os.chdir('/Users/chelseajimenez/Desktop/Policy-Language-Analysis/data/BP_AR_3511')

# %%
# Board Policy 3511 Template Path 
reference_file_path = "/Users/chelseajimenez/Desktop/Policy-Language-Analysis/3511 CSBA BP - Energy and Water Management Template (2007).txt"
# CSV BP 3511 CLeaned Policy PDFs path 
csv_file_path = "/Users/chelseajimenez/Desktop/Policy-Language-Analysis/cleaned_data/BP3511_cleaned_policy_pdfs.csv"

# %%
# Use pandas to read CSV file 
data = pd.read_csv(csv_file_path)
with open(reference_file_path, 'r') as ref_file:
    reference_text = ref_file.read()
extracted_text_column = "BP3511: PDF Text"
# Clean data and drop NaN values 
data = data.dropna(subset=[extracted_text_column])

# %% [markdown]
# ###  Use Cosine Similarity to Compare School District Board Policy to Board Policy Template

# %%
# Prepare text data for TF-IDF vectorization
texts = data[extracted_text_column].fillna("").tolist()  # Handle missing values
texts.insert(0, reference_text)  # Add the reference text as the first entry

# Compute TF-IDF and cosine similarity
vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(texts)
cosine_similarities = cosine_similarity(tfidf_matrix[0:1], tfidf_matrix[1:]).flatten()

# Add similarity scores to the DataFrame
data['similarity_score'] = cosine_similarities

# Add a column to display the reference text alongside
data['reference_text'] = reference_text

# Select relevant columns for display
comparison_results = data[[extracted_text_column, 'reference_text', 'similarity_score']].sort_values(by='similarity_score', ascending=False)

# Display the results
comparison_results
# Out:
#                                       BP3511: PDF Text  \
# 613  book policy manual section 3000 business nonin...
# 300  business noninstructional operation bp 3511 en...
# 619  policy 3511 energy water management status ado...
# 515  business noninstructional operation bp 3511 en...
# 50   business noninstructional operation bp 3511 en...
# ..                                                 ...
# 334  policy 3511 energy water management status ado...
# 165  w n e u n f e c h l r c administrative service...
# 293  book policy manual section 3000 business servi...
# 594  policy 3511 energy water management status ado...
# 283  huntington beach union high school district bo...
#
#                                         reference_text  similarity_score
# 613  ﻿CSBA Sample - BP 3511\n\n\nBoard Policy \nBus...          0.144646
# 300  ﻿CSBA Sample - BP 3511\n\n\nBoard Policy \nBus...          0.124914
# 619  ﻿CSBA Sample - BP 3511\n\n\nBoard Policy \nBus...          0.123570
# 515  ﻿CSBA Sample - BP 3511\n\n\nBoard Policy \nBus...          0.123027
# 50   ﻿CSBA Sample - BP 3511\n\n\nBoard Policy \nBus...          0.122559
# ..                                                 ...               ...
# 334  ﻿CSBA Sample - BP 3511\n\n\nBoard Policy \nBus...          0.014627
# 165  ﻿CSBA Sample - BP 3511\n\n\nBoard Policy \nBus...          0.013389
# 293  ﻿CSBA Sample - BP 3511\n\n\nBoard Policy \nBus...          0.012205
# 594  ﻿CSBA Sample - BP 3511\n\n\nBoard Policy \nBus...          0.012034
# 283  ﻿CSBA Sample - BP 3511\n\n\nBoard Policy \nBus...          0.010939
#
# [622 rows x 3 columns]

# %%
# Middle of histogram is .06-.07
similarity_threshold = 0.06

# Count the number of board policies with similarity scores above the threshold
most_similar_policies_count = (data['similarity_score'] >= similarity_threshold).sum()

# Display count
print(f"Number of board policies most similar to the reference policy: {most_similar_policies_count}")
# Out:
# Number of board policies most similar to the reference policy: 456

# %%
# Plot histogram of similarity scores
plt.figure(figsize=(10, 6))
plt.hist(data['similarity_score'], bins=20, color ='skyblue', edgecolor='black', alpha=0.7)
plt.title('Distribution of BP3511 Similarity to BP3511 Template ', fontsize=16)
plt.xlabel('Similarity Score', fontsize=14)
plt.ylabel('Frequency', fontsize=14)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ### Compare cosine similarity scores to overall score- does greater similarity to BP template equal higher sustainability score?

# %%
# Compare similarity scores with District-Wide Campus Sustainability Indicators (up to 3)
data[["District-Wide Campus Sustainability Indicators (up to 3)", "similarity_score"]]

#Sort data from highest to lowest sustainability score
sort_data = data.sort_values(by= "similarity_score", ascending = False)
sort_data[["District Name", "District-Wide Campus Sustainability Indicators (up to 3)", "similarity_score"]]
# Out:
#                      District Name  \
# 613          Conejo Valley Unified
# 300  Placer Hills Union Elementary
# 619             Washington Unified
# 515              Vacaville Unified
# 50          Black Oak Mine Unified
# ..                             ...
# 334               San Juan Unified
# 165                 Downey Unified
# 293                 Tustin Unified
# 594           Farmersville Unified
# 283    Huntington Beach Union High
#
#      District-Wide Campus Sustainability Indicators (up to 3)  \
# 613                                               0.50
# 300                                               0.00
# 619                                               1.50
# 515                                               1.00
# 50                                                2.50
# ..                                                 ...
# 334                                               3.00
# 165                                               0.75
# 293                                               3.00
# 594                                               0.50
# 283                                               2.75
#
#      similarity_score
# 613          0.144646
# 300          0.124914
# 619          0.123570
# 515          0.123027
# 50           0.122559
# ..                ...
# 334          0.014627
# 165          0.013389
# 293          0.012205
# 594          0.012034
# 283          0.010939
#
# [622 rows x 3 columns]

# %% [markdown]
# ### Distribution of District-Wide Campus Sustainability Indicators (up to 3) Across School Districts

# %%
# Distribution of District-Wide Campus Sustainability Indicators (up to 3) Across School Districts
plt.figure(figsize=(10,6))
plt.hist(data["District-Wide Campus Sustainability Indicators (up to 3)"], bins=10, color='skyblue')
plt.xlabel('District-Wide Campus Sustainability Indicators (up to 3)')
plt.ylabel('Frequency')
plt.title('Distribution of District-Wide Campus Sustainability Indicators (up to 3) Across School Districts')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Low Campus Sustainability Score vs Similarity Scores Against Template

# %%
# Dataframe for low campus sustainability score vs similarity score to template
low_sustainability_score = 1.5 
low_sustainability_data = data[data["District-Wide Campus Sustainability Indicators (up to 3)"] <= low_sustainability_score]
low_sustainability_df = low_sustainability_data[["District Name", "District-Wide Campus Sustainability Indicators (up to 3)", "similarity_score"]]
low_sustainability_df
# Out:
#                        District Name  \
# 16   Golden Feather Union Elementary
# 25                   Maxwell Unified
# 44         Gold Oak Union Elementary
# 45       Gold Trail Union Elementary
# 47                           Latrobe
# ..                               ...
# 619               Washington Unified
# 620            Winters Joint Unified
# 621           Woodland Joint Unified
# 622         Marysville Joint Unified
# 623           Plumas Lake Elementary
#
#      District-Wide Campus Sustainability Indicators (up to 3)  \
# 16                                                 1.0
# 25                                                 1.0
# 44                                                 1.0
# 45                                                 1.5
# 47                                                 1.0
# ..                                                 ...
# 619                                                1.5
# 620                                                0.5
# 621                                                1.0
# 622                                                1.5
# 623                                                0.5
#
#      similarity_score
# 16           0.051419
# 25           0.047253
# 44           0.077745
# 45           0.066398
# 47           0.051084
# ..                ...
# 619          0.123570
# 620          0.107838
# 621          0.042932
# 622          0.085963
# 623          0.086591
#
# [281 rows x 3 columns]

# %%
# Bar chart for low sustainability school districts 
plt.figure(figsize=(12,6))
plt.bar(low_sustainability_df['District Name'], low_sustainability_df['similarity_score'], color= 'skyblue')
plt.xlabel('District Name', fontsize=12)
plt.ylabel('Similarity Score Against Template', fontsize=12)
plt.title("Low Sustainability School Districts vs Similarity Scores Against Template", fontsize =14)
plt.xticks(rotation = 45, ha='right', fontsize=10)
plt.tight_layout()
plt.show()

# %%
# Dataframe for high sustainability score vs similarity score to template
high_sustainability_score = 1.5
high_sustainability_data = data[data["District-Wide Campus Sustainability Indicators (up to 3)"] > high_sustainability_score]
high_sustainability_df = high_sustainability_data[["District Name", "District-Wide Campus Sustainability Indicators (up to 3)", "similarity_score"]]
high_sustainability_df
# Out:
#              District Name  \
# 0          Alameda Unified
# 1      Albany City Unified
# 2    Castro Valley Unified
# 3          Hayward Unified
# 4           Newark Unified
# ..                     ...
# 595    Porterville Unified
# 597         Exeter Unified
# 615       Moorpark Unified
# 617    Davis Joint Unified
# 624   Wheatland Union High
#
#      District-Wide Campus Sustainability Indicators (up to 3)  \
# 0                                                 3.00
# 1                                                 3.00
# 2                                                 3.00
# 3                                                 3.00
# 4                                                 2.00
# ..                                                 ...
# 595                                               3.00
# 597                                               1.75
# 615                                               1.75
# 617                                               2.00
# 624                                               2.75
#
#      similarity_score
# 0            0.065205
# 1            0.046619
# 2            0.108792
# 3            0.042800
# 4            0.047801
# ..                ...
# 595          0.065358
# 597          0.067723
# 615          0.066106
# 617          0.066207
# 624          0.081568
#
# [341 rows x 3 columns]

# %%
# Plot low sustainability districts versus low similarity scores 
low_sustainability_threshold = 1.5
low_similarity_threshold = .04
data = data.dropna(subset=["District-Wide Campus Sustainability Indicators (up to 3)", "similarity_score"])
high_sustainability_low_similarity = data[(data["District-Wide Campus Sustainability Indicators (up to 3)"] < low_sustainability_threshold) & (data["similarity_score"] < low_similarity_threshold)]
filtered_df = high_sustainability_low_similarity[['District Name', "District-Wide Campus Sustainability Indicators (up to 3)", 'similarity_score']]
plt.figure(figsize=(10,6))
plt.bar(filtered_df['District Name'], filtered_df['similarity_score'], color='lightcoral')
plt.title("Low Sustainability Districts vs Low Similarity Scores Against Template")
plt.xlabel("School District")
plt.ylabel("Similarity Scores Against Template")
plt.tight_layout()
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.show()

# %%
# plot low sustainability districts versus high similarity scores 
low_sustainability_threshold = 1.5
high_similarity_threshold = .12
data = data.dropna(subset=["District-Wide Campus Sustainability Indicators (up to 3)", "similarity_score"])
high_sustainability_low_similarity = data[(data["District-Wide Campus Sustainability Indicators (up to 3)"] < low_sustainability_threshold) & (data["similarity_score"] < high_similarity_threshold)]
filtered_df = high_sustainability_low_similarity[['District Name', "District-Wide Campus Sustainability Indicators (up to 3)", 'similarity_score']]
plt.figure(figsize=(10,6))
plt.bar(filtered_df['District Name'], filtered_df['similarity_score'], color='lightcoral')
plt.title("Low Sustainability Districts vs High Similarity Scores Against Template")
plt.xlabel("School District")
plt.ylabel("Similarity Scores Against Template")
plt.tight_layout()
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.show()

# %%
# plot high sustainability districts versus low similarity scores - makes me think they care more bc its unique 
high_sustainability_threshold = 1.5
low_similarity_threshold = .04
data = data.dropna(subset=["District-Wide Campus Sustainability Indicators (up to 3)", "similarity_score"])
high_sustainability_low_similarity = data[(data["District-Wide Campus Sustainability Indicators (up to 3)"] > high_sustainability_threshold) & (data["similarity_score"] < low_similarity_threshold)]
filtered_df = high_sustainability_low_similarity[['District Name', "District-Wide Campus Sustainability Indicators (up to 3)", 'similarity_score']]
plt.figure(figsize=(10,6))
plt.bar(filtered_df['District Name'], filtered_df['similarity_score'], color='lightcoral')
plt.title("High Sustainability Districts vs Low Similarity Scores Against Template")
plt.xlabel("School District")
plt.ylabel("Similarity Scores Against Template")
plt.tight_layout()
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.show()

# %%
# plot high sustainability districts versus high similarity scores 
high_sustainability_threshold = 1.5
high_similarity_threshold = .11
data = data.dropna(subset=["District-Wide Campus Sustainability Indicators (up to 3)", "similarity_score"])
high_sustainability_low_similarity = data[(data["District-Wide Campus Sustainability Indicators (up to 3)"] > high_sustainability_threshold) & (data["similarity_score"] > high_similarity_threshold)]
filtered_df = high_sustainability_low_similarity[['District Name', "District-Wide Campus Sustainability Indicators (up to 3)", 'similarity_score']]
plt.figure(figsize=(10,6))
plt.bar(filtered_df['District Name'], filtered_df['similarity_score'], color='lightcoral')
plt.title("High Sustainability Districts vs High Similarity Scores Against Template")
plt.xlabel("School District")
plt.ylabel("Similarity Scores Against Template")
plt.tight_layout()
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.show()

# %% [markdown]
# ### Average School Board Policy Campus Sustainability Score by Student Enrollment Range

# %%
# Ensure 'Student Enrollment' and 'Campus Sustainability Score' are numeric and drop invalid rows
data['2023-24 Student Enrollment'] = pd.to_numeric(data['2023-24 Student Enrollment'], errors='coerce')
data['District-Wide Campus Sustainability Indicators (up to 3)'] = pd.to_numeric(data['District-Wide Campus Sustainability Indicators (up to 3)'], errors='coerce')
data = data.dropna(subset=['2023-24 Student Enrollment', 'District-Wide Campus Sustainability Indicators (up to 3)'])

# %%
# Create bins for student enrollment ranges
bins = [0, 500, 1000, 5000, 10000, float('inf')]  # Define ranges
labels = ['0-500', '501-1000', '1001-5000', '5001-10000', '10000+']
data['Enrollment Range'] = pd.cut(data['2023-24 Student Enrollment'], bins=bins, labels=labels)

# Calculate average Campus Sustainability Score by enrollment range
grouped_data = data.groupby('Enrollment Range', observed=True)['District-Wide Campus Sustainability Indicators (up to 3)'].mean()

# Display results
print("Average District-Wide Campus Sustainability Indicators (up to 3) Score by Student Enrollment Range:")
print(grouped_data)

# Bar plot for grouped data
grouped_data.plot(kind='bar', color='skyblue', edgecolor='black', figsize=(10, 6))
plt.xlabel('Student Enrollment Range', fontsize=12)
plt.ylabel('Average Campus Sustainability Score', fontsize=12)
plt.title('Average Campus Sustainability Score by Student Enrollment Range', fontsize=14)
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# Average District-Wide Campus Sustainability Indicators (up to 3) Score by Student Enrollment Range:
# Enrollment Range
# 0-500         1.440265
# 501-1000      1.513393
# 1001-5000     1.731760
# 5001-10000    2.142473
# 10000+        2.114173
# Name: District-Wide Campus Sustainability Indicators (up to 3), dtype: float64

# %% [markdown]
# ### Do newer updated policies align more with template and have a higher score or do old policies align less with template and have a lower score?

# %%
# Updated policies 
policy_updated = 'BP 3511 Year of Policy Update if applicable' 
year_threshold = 2020
data[policy_updated]=pd.to_numeric(data[policy_updated], errors='coerce')
data = data.dropna(subset=[policy_updated])
recent_policies = data[data[policy_updated] > year_threshold]
recent_policies[[policy_updated]]
# print(recent_policies[[policy_updated]])
# Out:
#      BP 3511 Year of Policy Update if applicable
# 9                                         2022.0
# 19                                        2021.0
# 31                                        2022.0
# 32                                        2023.0
# 34                                        2022.0
# ..                                           ...
# 560                                       2022.0
# 577                                       2022.0
# 606                                       2022.0
# 611                                       2023.0
# 612                                       2021.0
#
# [94 rows x 1 columns]

# %%
# Scatter plot: Update Year vs Similarity Score
plt.figure(figsize=(12, 6))
plt.scatter(data[policy_updated], data['similarity_score'], color='skyblue', edgecolor='black', alpha=0.7)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Similarity Score Against Template', fontsize=12)
plt.title('Year of Policy Update vs Similarity Score Against Template', fontsize=14)
plt.grid(alpha=0.3)
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Filter data for policies updated before 2007
filtered_data = data[data[policy_updated] < 2007]

# Scatter plot: Update Year vs Similarity Score
plt.figure(figsize=(12, 6))
plt.scatter(filtered_data[policy_updated], filtered_data['similarity_score'], color='skyblue', edgecolor='black', alpha=0.7)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Similarity Score Against Template', fontsize=12)
plt.title('Year of Policy Update vs Similarity Score Against Template (Before 2007)', fontsize=14)
plt.grid(alpha=0.3)
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Filter data for policies updated before 2007
filtered_data = data[data[policy_updated] < 2007]

# Calculate the average Campus Sustainability Score
average_sustainability_score = filtered_data['District-Wide Campus Sustainability Indicators (up to 3)'].mean()

# Display the result
print(f"The average sustainability score for policies updated before 2007 is: {average_sustainability_score:.2f}")
# Out:
# The average sustainability score for policies updated before 2007 is: 2.25

# %%
# Filter data for policies updated after 2007
filtered_data = data[data[policy_updated] > 2007]

# Scatter plot: Update Year vs Similarity Score
plt.figure(figsize=(12, 6))
plt.scatter(filtered_data[policy_updated], filtered_data['similarity_score'], color='skyblue', edgecolor='black', alpha=0.7)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Similarity Score Against Template', fontsize=12)
plt.title('Year of Policy Update vs Similarity Score Against Template (After 2007)', fontsize=14)
plt.grid(alpha=0.3)
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Filter data for policies updated before 2007
filtered_data = data[data[policy_updated] > 2007]

# Calculate the average Campus Sustainability Score
average_sustainability_score = filtered_data['District-Wide Campus Sustainability Indicators (up to 3)'].mean()

# Display the result
print(f"The average sustainability score for policies updated after 2007 is: {average_sustainability_score:.2f}")
# Out:
# The average sustainability score for policies updated after 2007 is: 1.79

# %%
# Scatter plot: Update Year vs Similarity Score
policy_adopted = 'BP 3511 Year Adopted' 
data = data.sort_values(by=policy_adopted)
plt.figure(figsize=(12, 6))
plt.scatter(data[policy_adopted], data['similarity_score'], color='skyblue', edgecolor='black', alpha=0.7)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Similarity Score Against Template', fontsize=12)
plt.title('Year of Policy Update vs Similarity Score Against Template', fontsize=14)
plt.grid(alpha=0.3)
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ### Word Count within Board Policies

# %%
# Function to calculate word count
def word_count(text):
    if pd.notnull(text):  # Check for non-null values
        return len(str(text).split())  # Split text into words and count
    return 0  # Return 0 for missing or invalid text

# Add a word count column
data['word_count'] = data[extracted_text_column].apply(word_count)

# Display the word count for each row with dynamic row numbers
print("Word Counts for Extracted Texts:\n")
for index, row in data.iterrows():
    extracted_text = row[extracted_text_column]
    word_count_value = row['word_count']
    print(f"Row {index + 1} Word Count: {word_count_value}")
# Out:
# Word Counts for Extracted Texts:
#
# Row 294 Word Count: 111
# Row 52 Word Count: 595
# Row 260 Word Count: 678
# Row 339 Word Count: 462
# Row 292 Word Count: 305
# Row 315 Word Count: 342
# Row 284 Word Count: 90
# Row 152 Word Count: 157
# Row 293 Word Count: 393
# Row 45 Word Count: 289
# Row 337 Word Count: 287
# Row 42 Word Count: 113
# Row 282 Word Count: 249
# Row 508 Word Count: 705
# Row 65 Word Count: 128
# Row 199 Word Count: 132
# Row 226 Word Count: 343
# Row 370 Word Count: 682
# Row 335 Word Count: 83
# Row 171 Word Count: 323
# Row 86 Word Count: 350
# Row 396 Word Count: 350
# Row 54 Word Count: 284
# Row 287 Word Count: 340
# Row 567 Word Count: 148
# Row 514 Word Count: 361
# Row 348 Word Count: 671
# Row 358 Word Count: 172
# Row 319 Word Count: 343
# Row 593 Word Count: 693
# Row 313 Word Count: 283
# Row 365 Word Count: 264
# Row 462 Word Count: 329
# Row 461 Word Count: 329
# Row 165 Word Count: 159
# Row 359 Word Count: 343
# Row 151 Word Count: 141
# Row 154 Word Count: 109
# Row 61 Word Count: 593
# Row 186 Word Count: 114
# Row 20 Word Count: 342
# Row 19 Word Count: 670
# Row 354 Word Count: 343
# Row 247 Word Count: 346
# Row 466 Word Count: 307
# Row 273 Word Count: 221
# Row 621 Word Count: 630
# Row 270 Word Count: 338
# Row 204 Word Count: 298
# Row 123 Word Count: 517
# Row 266 Word Count: 491
# Row 507 Word Count: 338
# Row 381 Word Count: 573
# Row 219 Word Count: 146
# Row 21 Word Count: 344
# Row 230 Word Count: 356
# Row 346 Word Count: 338
# Row 422 Word Count: 109
# Row 419 Word Count: 352
# Row 232 Word Count: 341
# Row 411 Word Count: 677
# Row 44 Word Count: 383
# Row 189 Word Count: 309
# Row 289 Word Count: 132
# Row 190 Word Count: 342
# Row 352 Word Count: 126
# Row 50 Word Count: 339
# Row 198 Word Count: 559
# Row 35 Word Count: 343
# Row 374 Word Count: 661
# Row 576 Word Count: 342
# Row 494 Word Count: 338
# Row 4 Word Count: 137
# Row 489 Word Count: 343
# Row 561 Word Count: 343
# Row 531 Word Count: 308
# Row 607 Word Count: 338
# Row 166 Word Count: 46
# Row 297 Word Count: 285
# Row 532 Word Count: 308
# Row 205 Word Count: 302
# Row 216 Word Count: 343
# Row 377 Word Count: 375
# Row 202 Word Count: 112
# Row 185 Word Count: 225
# Row 363 Word Count: 493
# Row 173 Word Count: 406
# Row 351 Word Count: 334
# Row 7 Word Count: 292
# Row 9 Word Count: 336
# Row 218 Word Count: 481
# Row 279 Word Count: 344
# Row 195 Word Count: 424
# Row 464 Word Count: 530
# Row 327 Word Count: 347
# Row 516 Word Count: 491
# Row 174 Word Count: 139
# Row 555 Word Count: 517
# Row 242 Word Count: 308
# Row 612 Word Count: 341
# Row 207 Word Count: 342
# Row 172 Word Count: 267
# Row 475 Word Count: 158
# Row 399 Word Count: 342
# Row 39 Word Count: 185
# Row 290 Word Count: 291
# Row 15 Word Count: 144
# Row 345 Word Count: 238
# Row 244 Word Count: 322
# Row 97 Word Count: 307
# Row 605 Word Count: 691
# Row 534 Word Count: 342
# Row 215 Word Count: 702
# Row 535 Word Count: 342
# Row 610 Word Count: 306
# Row 310 Word Count: 342
# Row 538 Word Count: 343
# Row 114 Word Count: 135
# Row 332 Word Count: 343
# Row 64 Word Count: 344
# Row 196 Word Count: 343
# Row 321 Word Count: 343
# Row 30 Word Count: 343
# Row 402 Word Count: 342
# Row 392 Word Count: 343
# Row 48 Word Count: 341
# Row 449 Word Count: 342
# Row 544 Word Count: 160
# Row 510 Word Count: 343
# Row 503 Word Count: 304
# Row 115 Word Count: 342
# Row 134 Word Count: 305
# Row 501 Word Count: 221
# Row 347 Word Count: 342
# Row 611 Word Count: 342
# Row 608 Word Count: 135
# Row 163 Word Count: 135
# Row 325 Word Count: 309
# Row 623 Word Count: 310
# Row 298 Word Count: 303
# Row 323 Word Count: 339
# Row 121 Word Count: 343
# Row 585 Word Count: 343
# Row 224 Word Count: 136
# Row 573 Word Count: 136
# Row 483 Word Count: 195
# Row 49 Word Count: 342
# Row 495 Word Count: 304
# Row 397 Word Count: 250
# Row 309 Word Count: 342
# Row 572 Word Count: 303
# Row 546 Word Count: 342
# Row 316 Word Count: 137
# Row 201 Word Count: 504
# Row 388 Word Count: 342
# Row 223 Word Count: 136
# Row 454 Word Count: 191
# Row 133 Word Count: 308
# Row 338 Word Count: 421
# Row 614 Word Count: 588
# Row 615 Word Count: 691
# Row 148 Word Count: 173
# Row 149 Word Count: 160
# Row 208 Word Count: 136
# Row 375 Word Count: 456
# Row 604 Word Count: 346
# Row 94 Word Count: 450
# Row 429 Word Count: 341
# Row 427 Word Count: 685
# Row 251 Word Count: 343
# Row 468 Word Count: 342
# Row 288 Word Count: 349
# Row 194 Word Count: 136
# Row 255 Word Count: 338
# Row 385 Word Count: 264
# Row 342 Word Count: 163
# Row 314 Word Count: 342
# Row 393 Word Count: 600
# Row 380 Word Count: 341
# Row 1 Word Count: 342
# Row 184 Word Count: 303
# Row 447 Word Count: 304
# Row 558 Word Count: 136
# Row 559 Word Count: 160
# Row 571 Word Count: 303
# Row 574 Word Count: 161
# Row 592 Word Count: 343
# Row 157 Word Count: 343
# Row 92 Word Count: 342
# Row 446 Word Count: 303
# Row 122 Word Count: 346
# Row 2 Word Count: 238
# Row 417 Word Count: 1119
# Row 618 Word Count: 302
# Row 415 Word Count: 303
# Row 25 Word Count: 135
# Row 113 Word Count: 357
# Row 93 Word Count: 304
# Row 376 Word Count: 292
# Row 225 Word Count: 304
# Row 108 Word Count: 136
# Row 500 Word Count: 342
# Row 526 Word Count: 303
# Row 104 Word Count: 135
# Row 187 Word Count: 339
# Row 479 Word Count: 209
# Row 87 Word Count: 344
# Row 548 Word Count: 342
# Row 435 Word Count: 265
# Row 550 Word Count: 237
# Row 398 Word Count: 338
# Row 300 Word Count: 342
# Row 197 Word Count: 155
# Row 162 Word Count: 140
# Row 161 Word Count: 344
# Row 423 Word Count: 303
# Row 603 Word Count: 135
# Row 329 Word Count: 342
# Row 426 Word Count: 134
# Row 31 Word Count: 339
# Row 111 Word Count: 303
# Row 256 Word Count: 343
# Row 563 Word Count: 304
# Row 53 Word Count: 301
# Row 73 Word Count: 304
# Row 252 Word Count: 338
# Row 271 Word Count: 664
# Row 277 Word Count: 342
# Row 272 Word Count: 344
# Row 624 Word Count: 304
# Row 109 Word Count: 342
# Row 517 Word Count: 392
# Row 350 Word Count: 134
# Row 214 Word Count: 342
# Row 395 Word Count: 166
# Row 191 Word Count: 987
# Row 410 Word Count: 135
# Row 307 Word Count: 448
# Row 382 Word Count: 342
# Row 379 Word Count: 304
# Row 110 Word Count: 305
# Row 460 Word Count: 166
# Row 308 Word Count: 164
# Row 486 Word Count: 343
# Row 481 Word Count: 136
# Row 369 Word Count: 338
# Row 485 Word Count: 343
# Row 91 Word Count: 261
# Row 384 Word Count: 303
# Row 569 Word Count: 343
# Row 169 Word Count: 632
# Row 509 Word Count: 168
# Row 51 Word Count: 489
# Row 55 Word Count: 133
# Row 283 Word Count: 136
# Row 60 Word Count: 140
# Row 17 Word Count: 339
# Row 221 Word Count: 164
# Row 153 Word Count: 342
# Row 228 Word Count: 298
# Row 469 Word Count: 345
# Row 488 Word Count: 132
# Row 135 Word Count: 303
# Row 536 Word Count: 341
# Row 83 Word Count: 136
# Row 264 Word Count: 358
# Row 443 Word Count: 160
# Row 432 Word Count: 344
# Row 291 Word Count: 126
# Row 183 Word Count: 290
# Row 147 Word Count: 170
# Row 237 Word Count: 303
# Row 458 Word Count: 136
# Row 470 Word Count: 136
# Row 59 Word Count: 338
# Row 305 Word Count: 370
# Row 268 Word Count: 343
# Row 125 Word Count: 330
# Row 545 Word Count: 669
# Row 378 Word Count: 143
# Row 82 Word Count: 332
# Row 67 Word Count: 135
# Row 424 Word Count: 146
# Row 434 Word Count: 336
# Row 317 Word Count: 289
# Row 565 Word Count: 136
# Row 562 Word Count: 136
# Row 320 Word Count: 149
# Row 438 Word Count: 342
# Row 542 Word Count: 303
# Row 537 Word Count: 265
# Row 340 Word Count: 305
# Row 575 Word Count: 343
# Row 353 Word Count: 238
# Row 301 Word Count: 491
# Row 68 Word Count: 136
# Row 156 Word Count: 342
# Row 250 Word Count: 340
# Row 8 Word Count: 343
# Row 164 Word Count: 261
# Row 265 Word Count: 319
# Row 34 Word Count: 339
# Row 372 Word Count: 343
# Row 231 Word Count: 304
# Row 217 Word Count: 130
# Row 18 Word Count: 102
# Row 182 Word Count: 1272
# Row 349 Word Count: 132
# Row 96 Word Count: 181
# Row 23 Word Count: 344
# Row 69 Word Count: 342
# Row 504 Word Count: 146
# Row 79 Word Count: 334
# Row 557 Word Count: 310
# Row 107 Word Count: 304
# Row 425 Word Count: 135
# Row 318 Word Count: 239
# Row 280 Word Count: 341
# Row 5 Word Count: 159
# Row 140 Word Count: 303
# Row 103 Word Count: 562
# Row 513 Word Count: 135
# Row 525 Word Count: 343
# Row 344 Word Count: 135
# Row 549 Word Count: 104
# Row 158 Word Count: 342
# Row 193 Word Count: 304
# Row 622 Word Count: 187
# Row 72 Word Count: 135
# Row 36 Word Count: 123
# Row 524 Word Count: 848
# Row 26 Word Count: 135
# Row 456 Word Count: 302
# Row 175 Word Count: 296
# Row 406 Word Count: 342
# Row 620 Word Count: 480
# Row 229 Word Count: 705
# Row 416 Word Count: 304
# Row 383 Word Count: 136
# Row 137 Word Count: 343
# Row 311 Word Count: 343
# Row 400 Word Count: 342
# Row 281 Word Count: 191
# Row 473 Word Count: 163
# Row 580 Word Count: 264
# Row 269 Word Count: 301
# Row 76 Word Count: 303
# Row 433 Word Count: 135
# Row 29 Word Count: 421
# Row 167 Word Count: 137
# Row 387 Word Count: 304
# Row 75 Word Count: 338
# Row 455 Word Count: 346
# Row 530 Word Count: 343
# Row 57 Word Count: 180
# Row 116 Word Count: 134
# Row 88 Word Count: 668
# Row 240 Word Count: 344
# Row 523 Word Count: 338
# Row 420 Word Count: 679
# Row 40 Word Count: 234
# Row 459 Word Count: 303
# Row 452 Word Count: 136
# Row 430 Word Count: 132
# Row 101 Word Count: 135
# Row 596 Word Count: 342
# Row 120 Word Count: 303
# Row 170 Word Count: 301
# Row 570 Word Count: 135
# Row 306 Word Count: 339
# Row 13 Word Count: 165
# Row 389 Word Count: 563
# Row 357 Word Count: 303
# Row 521 Word Count: 303
# Row 331 Word Count: 340
# Row 341 Word Count: 136
# Row 616 Word Count: 342
# Row 326 Word Count: 343
# Row 330 Word Count: 294
# Row 322 Word Count: 180
# Row 295 Word Count: 294
# Row 606 Word Count: 341
# Row 227 Word Count: 303
# Row 130 Word Count: 343
# Row 74 Word Count: 383
# Row 482 Word Count: 338
# Row 80 Word Count: 303
# Row 78 Word Count: 514
# Row 132 Word Count: 344
# Row 119 Word Count: 338
# Row 480 Word Count: 335
# Row 77 Word Count: 334
# Row 126 Word Count: 415
# Row 43 Word Count: 417
# Row 127 Word Count: 417
# Row 566 Word Count: 298
# Row 543 Word Count: 149
# Row 539 Word Count: 416
# Row 568 Word Count: 340
# Row 540 Word Count: 422
# Row 467 Word Count: 343
# Row 541 Word Count: 416
# Row 564 Word Count: 339
# Row 533 Word Count: 335
# Row 505 Word Count: 340
# Row 56 Word Count: 339
# Row 506 Word Count: 338
# Row 556 Word Count: 338
# Row 98 Word Count: 335
# Row 502 Word Count: 305
# Row 511 Word Count: 339
# Row 512 Word Count: 342
# Row 95 Word Count: 277
# Row 498 Word Count: 417
# Row 497 Word Count: 388
# Row 496 Word Count: 304
# Row 105 Word Count: 338
# Row 515 Word Count: 294
# Row 47 Word Count: 339
# Row 493 Word Count: 306
# Row 90 Word Count: 260
# Row 491 Word Count: 1076
# Row 89 Word Count: 338
# Row 518 Word Count: 337
# Row 519 Word Count: 294
# Row 520 Word Count: 199
# Row 112 Word Count: 338
# Row 522 Word Count: 338
# Row 560 Word Count: 338
# Row 527 Word Count: 333
# Row 551 Word Count: 338
# Row 529 Word Count: 339
# Row 492 Word Count: 340
# Row 625 Word Count: 417
# Row 428 Word Count: 85
# Row 139 Word Count: 338
# Row 241 Word Count: 339
# Row 355 Word Count: 339
# Row 239 Word Count: 336
# Row 238 Word Count: 281
# Row 360 Word Count: 347
# Row 236 Word Count: 338
# Row 22 Word Count: 668
# Row 234 Word Count: 313
# Row 367 Word Count: 299
# Row 368 Word Count: 339
# Row 233 Word Count: 339
# Row 373 Word Count: 339
# Row 222 Word Count: 337
# Row 220 Word Count: 271
# Row 213 Word Count: 262
# Row 16 Word Count: 338
# Row 246 Word Count: 338
# Row 249 Word Count: 344
# Row 253 Word Count: 338
# Row 303 Word Count: 338
# Row 6 Word Count: 650
# Row 619 Word Count: 338
# Row 324 Word Count: 339
# Row 276 Word Count: 674
# Row 617 Word Count: 340
# Row 274 Word Count: 335
# Row 211 Word Count: 340
# Row 11 Word Count: 291
# Row 336 Word Count: 339
# Row 263 Word Count: 417
# Row 12 Word Count: 343
# Row 261 Word Count: 336
# Row 343 Word Count: 343
# Row 258 Word Count: 337
# Row 257 Word Count: 729
# Row 267 Word Count: 339
# Row 210 Word Count: 191
# Row 209 Word Count: 160
# Row 386 Word Count: 339
# Row 159 Word Count: 349
# Row 70 Word Count: 338
# Row 155 Word Count: 299
# Row 28 Word Count: 334
# Row 146 Word Count: 338
# Row 145 Word Count: 305
# Row 437 Word Count: 339
# Row 160 Word Count: 656
# Row 144 Word Count: 339
# Row 440 Word Count: 340
# Row 441 Word Count: 331
# Row 583 Word Count: 308
# Row 444 Word Count: 235
# Row 37 Word Count: 351
# Row 450 Word Count: 338
# Row 453 Word Count: 665
# Row 439 Word Count: 201
# Row 138 Word Count: 227
# Row 27 Word Count: 339
# Row 413 Word Count: 299
# Row 203 Word Count: 337
# Row 391 Word Count: 592
# Row 24 Word Count: 338
# Row 394 Word Count: 310
# Row 181 Word Count: 304
# Row 179 Word Count: 338
# Row 602 Word Count: 410
# Row 168 Word Count: 300
# Row 601 Word Count: 416
# Row 403 Word Count: 342
# Row 404 Word Count: 338
# Row 600 Word Count: 417
# Row 599 Word Count: 670
# Row 412 Word Count: 338
# Row 177 Word Count: 135
# Row 547 Word Count: 338
# Row 62 Word Count: 338
# Row 58 Word Count: 135
# Row 304 Word Count: 304
# Row 150 Word Count: 339
# Row 178 Word Count: 189
# Row 188 Word Count: 415
# Row 364 Word Count: 191
# Row 259 Word Count: 339
# Row 142 Word Count: 339
# Row 448 Word Count: 338
# Row 421 Word Count: 671
# Row 471 Word Count: 343
# Row 118 Word Count: 251
# Row 484 Word Count: 214
# Row 275 Word Count: 746
# Row 409 Word Count: 340
# Row 85 Word Count: 135
# Row 302 Word Count: 351
# Row 106 Word Count: 338
# Row 99 Word Count: 292
# Row 212 Word Count: 132
# Row 554 Word Count: 191
# Row 100 Word Count: 137
# Row 102 Word Count: 343
# Row 487 Word Count: 110
# Row 613 Word Count: 294
# Row 285 Word Count: 396
# Row 477 Word Count: 337
# Row 38 Word Count: 281
# Row 299 Word Count: 338
# Row 10 Word Count: 353
# Row 362 Word Count: 339
# Row 328 Word Count: 337
# Row 312 Word Count: 339
# Row 180 Word Count: 337
# Row 262 Word Count: 337
# Row 136 Word Count: 109
# Row 445 Word Count: 190
# Row 578 Word Count: 337
# Row 32 Word Count: 338
# Row 41 Word Count: 264
# Row 414 Word Count: 108
# Row 528 Word Count: 338
# Row 490 Word Count: 338
# Row 117 Word Count: 338
# Row 296 Word Count: 338
# Row 128 Word Count: 339
# Row 278 Word Count: 339
# Row 129 Word Count: 100
# Row 131 Word Count: 339
# Row 457 Word Count: 339
# Row 176 Word Count: 351
# Row 141 Word Count: 338
# Row 33 Word Count: 335
# Row 245 Word Count: 338
# Row 206 Word Count: 191
# Row 71 Word Count: 665
# Row 431 Word Count: 337
# Row 401 Word Count: 339
# Row 334 Word Count: 215
# Row 84 Word Count: 337
# Row 143 Word Count: 720

# %%
# Plot for word count and Campus Sustainability Score
plt.figure(figsize=(10,6))
plt.scatter(data['word_count'], data['District-Wide Campus Sustainability Indicators (up to 3)'], color='skyblue')
plt.xlabel('Word Count', fontsize=12)
plt.grid(alpha=0.3)
plt.xlabel('Word Count')
plt.ylabel('District-Wide Campus Sustainability Indicators (up to 3)')
plt.title("Word Count vs District-Wide Campus Sustainability Indicators (up to 3)")
plt.tight_layout()

# %%
# plot word count and high Campus Sustainability Score- do higher scores means there is a higher word count? 
high_sustainability_data = data[data['District-Wide Campus Sustainability Indicators (up to 3)'] > 1.5]
plt.figure(figsize=(10,6))
plt.scatter(high_sustainability_data['word_count'], high_sustainability_data['District-Wide Campus Sustainability Indicators (up to 3)'], color ='skyblue')
plt.tight_layout()
plt.xlabel('Word Count')
plt.title("Word Count vs High District-Wide Campus Sustainability Indicators (up to 3) Score")
plt.ylabel('District-Wide Campus Sustainability Indicators (up to 3)')
plt.show()

# %%
# Plot word count and low sustainability scores- do higher scores means there is a higher word count? 
high_sustainability_data = data[data['District-Wide Campus Sustainability Indicators (up to 3)'] < 1.5]
plt.figure(figsize=(10,6))
plt.scatter(high_sustainability_data['word_count'], high_sustainability_data['District-Wide Campus Sustainability Indicators (up to 3)'], color ='skyblue')
plt.tight_layout()
plt.xlabel('Word Count')
plt.title("Word Count vs Low District-Wide Campus Sustainability Indicators (up to 3)")
plt.ylabel('District-Wide Campus Sustainability Indicators (up to 3)')
plt.show()

# %%
# Find average word count for Campus Sustainability Score of 3 
sustainability_score_three = data[data['District-Wide Campus Sustainability Indicators (up to 3)'] == 3]
average_word_count = sustainability_score_three['word_count'].mean()
print(f"The average word count for District-Wide Campus Sustainability Indicators Score of 3 is: {average_word_count:.2f}")
# Out:
# The average word count for District-Wide Campus Sustainability Indicators Score of 3 is: 327.61

# %%
# Find average word count for Campus Sustainability Scores below 1.5 
sustainability_score_three = data[data['District-Wide Campus Sustainability Indicators (up to 3)'] < 1.5]
average_word_count = sustainability_score_three['word_count'].mean()
print(f"The average word count for District-Wide Campus Sustainability Indicators Score below 1.5 is: {average_word_count:.2f}")
# Out:
# The average word count for District-Wide Campus Sustainability Indicators Score below 1.5 is: 320.10

# %% [markdown]
# ### Average Campus Sustainability Score by Word Count Range

# %%
# Create word count bins
data['Word Count Range'] = pd.cut(data['word_count'], bins=[0, 100, 200, 300, 400, float('inf')], 
                                  labels=['0-100', '101-200', '201-300', '301-400', '400+'])

# Calculate average Campus Sustainability Score for each range
avg_score_by_range = data.groupby('Word Count Range', observed= True)['District-Wide Campus Sustainability Indicators (up to 3)'].mean()

# Print the result
print("Average Campus Sustainability Score by Word Count Range:")
print(avg_score_by_range)
# Out:
# Average Campus Sustainability Score by Word Count Range:
# Word Count Range
# 0-100      2.050000
# 101-200    1.808190
# 201-300    1.870690
# 301-400    1.735016
# 400+       1.970779
# Name: District-Wide Campus Sustainability Indicators (up to 3), dtype: float64

# %%
# Bar plot for grouped data
avg_score_by_range.plot(kind='bar', color='skyblue', edgecolor='black', figsize=(10, 6))
plt.xlabel('Word Count Range', fontsize=12)
plt.ylabel('Average Campus Sustainability Score', fontsize=12)
plt.title('Average District-Wide Campus Sustainability Indicators (up to 3) Score by Word Count Range', fontsize=14)
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ### Word Frequency within Board Policies

# %%
# Calculate word frequency 
def word_frequency(text):
    if pd.notnull(text):
        words = str(text).lower().split()
        return Counter(words)
    return Counter()
extracted_text_column = "BP3511: PDF Text"
data['word_frequency'] = data[extracted_text_column].apply(word_frequency)

for index, row in data.iterrows():
    print(f"Row {index + 1} Word Frequency:")
    filtered_words = {word: count for word, count in row['word_frequency'].items() if count > 6 and word != 'cf'}
    print(filtered_words)
    print("-" * 80)
# Out:
# Row 294 Word Frequency:
# {}
# --------------------------------------------------------------------------------
# Row 52 Word Frequency:
# {'board': 9, 'district': 23, 'conservation': 9, 'energy': 30, 'water': 26, 'program': 11, 'management': 10, 'shall': 10, 'code': 8}
# --------------------------------------------------------------------------------
# Row 260 Word Frequency:
# {'school': 12, 'district': 16, 'energy': 11, 'water': 21, 'management': 16, 'resource': 10, 'goal': 7, 'superintendent': 9, 'designee': 9, 'shall': 12, 'plan': 7, 'code': 8, 'california': 7, 'http': 11}
# --------------------------------------------------------------------------------
# Row 339 Word Frequency:
# {'energy': 9, 'water': 15, 'management': 12, 'resource': 10, 'district': 11, 'superintendent': 9, 'designee': 9, 'shall': 11, 'code': 7}
# --------------------------------------------------------------------------------
# Row 292 Word Frequency:
# {'district': 13, 'energy': 18, 'water': 8, 'conservation': 11, 'help': 7, 'shall': 11}
# --------------------------------------------------------------------------------
# Row 315 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 12, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 284 Word Frequency:
# {}
# --------------------------------------------------------------------------------
# Row 152 Word Frequency:
# {'district': 7}
# --------------------------------------------------------------------------------
# Row 293 Word Frequency:
# {'district': 14, 'energy': 10, 'water': 12, 'board': 7, 'shall': 13, 'goal': 7, 'resource': 8, 'superintendent': 9, 'designee': 9, 'management': 8}
# --------------------------------------------------------------------------------
# Row 45 Word Frequency:
# {'energy': 15, 'water': 7, 'district': 11, 'help': 7, 'shall': 10}
# --------------------------------------------------------------------------------
# Row 337 Word Frequency:
# {'energy': 8, 'water': 7, 'management': 9, 'resource': 8}
# --------------------------------------------------------------------------------
# Row 42 Word Frequency:
# {}
# --------------------------------------------------------------------------------
# Row 282 Word Frequency:
# {'energy': 22, 'water': 8, 'conservation': 12, 'district': 9}
# --------------------------------------------------------------------------------
# Row 508 Word Frequency:
# {'school': 12, 'district': 15, 'california': 12, 'energy': 10, 'water': 20, 'management': 17, 'resource': 12, 'goal': 7, 'superintendent': 9, 'designee': 9, 'shall': 12, 'use': 7, 'plan': 7, 'code': 8, 'emergency': 7, 'http': 11}
# --------------------------------------------------------------------------------
# Row 65 Word Frequency:
# {'energy': 8}
# --------------------------------------------------------------------------------
# Row 199 Word Frequency:
# {'energy': 9}
# --------------------------------------------------------------------------------
# Row 226 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 12, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 370 Word Frequency:
# {'operation': 7, 'energy': 11, 'water': 17, 'management': 18, 'resource': 12, 'district': 13, 'goal': 7, 'superintendent': 9, 'designee': 9, 'shall': 12, 'use': 7, 'school': 10, 'plan': 7, 'code': 8, 'emergency': 7, 'california': 10, 'http': 11}
# --------------------------------------------------------------------------------
# Row 335 Word Frequency:
# {}
# --------------------------------------------------------------------------------
# Row 171 Word Frequency:
# {'energy': 8, 'water': 7, 'management': 9, 'code': 7, 'resource': 8, 'http': 8}
# --------------------------------------------------------------------------------
# Row 86 Word Frequency:
# {'water': 8, 'management': 10, 'district': 9, 'superintendent': 7, 'designee': 7, 'shall': 7, 'plan': 7}
# --------------------------------------------------------------------------------
# Row 396 Word Frequency:
# {'water': 8, 'management': 10, 'district': 9, 'superintendent': 7, 'designee': 7, 'shall': 7, 'plan': 7}
# --------------------------------------------------------------------------------
# Row 54 Word Frequency:
# {'energy': 15, 'district': 11, 'help': 7, 'shall': 10}
# --------------------------------------------------------------------------------
# Row 287 Word Frequency:
# {'water': 11, 'management': 10, 'district': 12, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 567 Word Frequency:
# {'district': 8, 'energy': 7}
# --------------------------------------------------------------------------------
# Row 514 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 13, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 348 Word Frequency:
# {'energy': 10, 'water': 20, 'management': 17, 'board': 7, 'resource': 12, 'district': 13, 'goal': 7, 'superintendent': 9, 'designee': 9, 'shall': 12, 'use': 7, 'school': 11, 'plan': 7, 'code': 8, 'emergency': 7, 'california': 10}
# --------------------------------------------------------------------------------
# Row 358 Word Frequency:
# {'district': 7}
# --------------------------------------------------------------------------------
# Row 319 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 12, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 593 Word Frequency:
# {'energy': 11, 'water': 21, 'management': 19, 'resource': 13, 'district': 13, 'goal': 7, 'superintendent': 9, 'designee': 9, 'shall': 12, 'use': 7, 'school': 10, 'plan': 7, 'code': 8, 'emergency': 7, 'california': 10, 'http': 11}
# --------------------------------------------------------------------------------
# Row 313 Word Frequency:
# {'energy': 9, 'district': 13, 'resource': 7, 'superintendent': 7, 'designee': 7, 'shall': 8, 'plan': 7}
# --------------------------------------------------------------------------------
# Row 365 Word Frequency:
# {'energy': 14, 'district': 11, 'help': 7, 'shall': 10}
# --------------------------------------------------------------------------------
# Row 462 Word Frequency:
# {'water': 11, 'management': 9, 'district': 11, 'superintendent': 8, 'designee': 8, 'shall': 11}
# --------------------------------------------------------------------------------
# Row 461 Word Frequency:
# {'water': 11, 'management': 9, 'district': 11, 'superintendent': 8, 'designee': 8, 'shall': 11}
# --------------------------------------------------------------------------------
# Row 165 Word Frequency:
# {'energy': 7}
# --------------------------------------------------------------------------------
# Row 359 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 12, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 151 Word Frequency:
# {'energy': 9}
# --------------------------------------------------------------------------------
# Row 154 Word Frequency:
# {}
# --------------------------------------------------------------------------------
# Row 61 Word Frequency:
# {'board': 7, 'school': 10, 'district': 12, 'energy': 8, 'water': 15, 'management': 15, 'resource': 12, 'goal': 7, 'superintendent': 8, 'designee': 8, 'shall': 9, 'use': 7, 'code': 8, 'california': 9, 'http': 11}
# --------------------------------------------------------------------------------
# Row 186 Word Frequency:
# {'energy': 7}
# --------------------------------------------------------------------------------
# Row 20 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 12, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 19 Word Frequency:
# {'energy': 8, 'water': 18, 'management': 15, 'board': 7, 'resource': 12, 'district': 12, 'goal': 7, 'superintendent': 9, 'designee': 9, 'shall': 12, 'use': 7, 'school': 9, 'plan': 7, 'code': 8, 'emergency': 7, 'california': 9, 'http': 11}
# --------------------------------------------------------------------------------
# Row 354 Word Frequency:
# {'water': 11, 'resource': 7, 'district': 12, 'management': 10, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 247 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 12, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 466 Word Frequency:
# {'water': 13, 'management': 9, 'board': 8, 'district': 12, 'superintendent': 7, 'designee': 7, 'shall': 9}
# --------------------------------------------------------------------------------
# Row 273 Word Frequency:
# {'district': 8}
# --------------------------------------------------------------------------------
# Row 621 Word Frequency:
# {'energy': 10, 'water': 20, 'management': 18, 'resource': 13, 'district': 13, 'goal': 7, 'superintendent': 8, 'designee': 8, 'shall': 10, 'use': 7, 'school': 10, 'code': 8, 'california': 10, 'http': 11}
# --------------------------------------------------------------------------------
# Row 270 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 12, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 204 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 12, 'superintendent': 8, 'designee': 8, 'shall': 10}
# --------------------------------------------------------------------------------
# Row 123 Word Frequency:
# {'operation': 8, 'energy': 24, 'water': 13, 'district': 18, 'conservation': 10, 's': 10, 'help': 7, 'shall': 14, 'goal': 7, 'superintendent': 7, 'designee': 7, 'use': 8, 'http': 7}
# --------------------------------------------------------------------------------
# Row 266 Word Frequency:
# {'energy': 9, 'water': 19, 'management': 16, 'board': 8, 'district': 12, 'resource': 10, 'superintendent': 7, 'designee': 7, 'shall': 9, 'plan': 7, 'storm': 7, 'discharge': 7, 'california': 7}
# --------------------------------------------------------------------------------
# Row 507 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 12, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 381 Word Frequency:
# {'energy': 15, 'water': 13, 'code': 8, 'resource': 7, 'district': 9, 'management': 7, 'superintendent': 8, 'designee': 8, 'shall': 12, 'school': 8, 'http': 13, 'california': 10}
# --------------------------------------------------------------------------------
# Row 219 Word Frequency:
# {}
# --------------------------------------------------------------------------------
# Row 21 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 12, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 230 Word Frequency:
# {'water': 12, 'management': 11, 'resource': 7, 'district': 11, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 346 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 12, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 422 Word Frequency:
# {'energy': 9}
# --------------------------------------------------------------------------------
# Row 419 Word Frequency:
# {'water': 12, 'management': 11, 'resource': 7, 'district': 12, 'superintendentprincipal': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 232 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 11, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 411 Word Frequency:
# {'energy': 10, 'water': 20, 'management': 17, 'resource': 12, 'district': 13, 'goal': 7, 'superintendent': 9, 'designee': 9, 'shall': 12, 'use': 7, 'school': 10, 'plan': 7, 'code': 8, 'emergency': 7, 'california': 10, 'http': 11}
# --------------------------------------------------------------------------------
# Row 44 Word Frequency:
# {'energy': 7, 'water': 11, 'management': 10, 'resource': 8, 'district': 13, 'goal': 7, 'superintendent': 10, 'designee': 10, 'shall': 13, 'program': 7}
# --------------------------------------------------------------------------------
# Row 189 Word Frequency:
# {'water': 14, 'management': 10, 'board': 7, 'district': 11, 'shall': 8}
# --------------------------------------------------------------------------------
# Row 289 Word Frequency:
# {'energy': 9}
# --------------------------------------------------------------------------------
# Row 190 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 12, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 352 Word Frequency:
# {}
# --------------------------------------------------------------------------------
# Row 50 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 12, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 198 Word Frequency:
# {'energy': 8, 'water': 14, 'conservation': 8, 'code': 8, 'district': 13, 'resource': 11, 'superintendent': 9, 'designee': 9, 'shall': 12, 'management': 11, 'plan': 7, 'http': 8, 'emergency': 7, 'california': 7}
# --------------------------------------------------------------------------------
# Row 35 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 12, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 374 Word Frequency:
# {'board': 7, 'energy': 8, 'water': 18, 'management': 15, 'resource': 12, 'district': 13, 'goal': 7, 'superintendent': 9, 'designee': 9, 'shall': 12, 'use': 7, 'school': 10, 'plan': 7, 'code': 8, 'emergency': 7, 'california': 10, 'http': 11}
# --------------------------------------------------------------------------------
# Row 576 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 12, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 494 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 12, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 4 Word Frequency:
# {'district': 7}
# --------------------------------------------------------------------------------
# Row 489 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 12, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 561 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 11, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 531 Word Frequency:
# {'water': 13, 'management': 9, 'board': 8, 'district': 12, 'superintendent': 7, 'designee': 7, 'shall': 9}
# --------------------------------------------------------------------------------
# Row 607 Word Frequency:
# {'water': 12, 'management': 11, 'resource': 7, 'district': 12, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 166 Word Frequency:
# {}
# --------------------------------------------------------------------------------
# Row 297 Word Frequency:
# {'water': 9, 'management': 10, 'district': 10, 'shall': 8}
# --------------------------------------------------------------------------------
# Row 532 Word Frequency:
# {'water': 13, 'management': 9, 'board': 8, 'district': 12, 'superintendent': 7, 'designee': 7, 'shall': 9}
# --------------------------------------------------------------------------------
# Row 205 Word Frequency:
# {'energy': 15, 'water': 7, 'district': 12, 'help': 7, 'shall': 10}
# --------------------------------------------------------------------------------
# Row 216 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 12, 'superintendent': 9, 'designee': 9, 'may': 8, 'shall': 9}
# --------------------------------------------------------------------------------
# Row 377 Word Frequency:
# {'energy': 8, 'water': 11, 'management': 10, 'board': 7, 'district': 12, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 202 Word Frequency:
# {'energy': 8}
# --------------------------------------------------------------------------------
# Row 185 Word Frequency:
# {'district': 12, 'energy': 15, 'help': 7, 'shall': 8}
# --------------------------------------------------------------------------------
# Row 363 Word Frequency:
# {'energy': 9, 'water': 13, 'management': 12, 'code': 9, 'resource': 11, 'district': 10, 'use': 7, 'school': 8, 'http': 13, 'california': 9}
# --------------------------------------------------------------------------------
# Row 173 Word Frequency:
# {'district': 18, 'energy': 16, 'water': 15, 'management': 9, 'shall': 7, 'use': 10}
# --------------------------------------------------------------------------------
# Row 351 Word Frequency:
# {'school': 7, 'district': 14, 'board': 10, 'energy': 19, 'shall': 10}
# --------------------------------------------------------------------------------
# Row 7 Word Frequency:
# {'district': 11, 'business': 7, 'energy': 14, 'help': 7, 'shall': 10, 'superintendent': 12}
# --------------------------------------------------------------------------------
# Row 9 Word Frequency:
# {'district': 12, 'water': 11, 'management': 10, 'resource': 7, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 218 Word Frequency:
# {'operation': 8, 'water': 17, 'conservation': 7, 'board': 7, 'district': 18, 's': 9, 'resource': 8, 'superintendent': 11, 'designee': 11, 'shall': 14, 'management': 12, 'program': 9, 'plan': 8}
# --------------------------------------------------------------------------------
# Row 279 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 12, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 195 Word Frequency:
# {'water': 11, 'management': 12, 'resource': 7, 'district': 13, 'goal': 7, 'superintendent': 9, 'designee': 9, 'shall': 12, 'plan': 7}
# --------------------------------------------------------------------------------
# Row 464 Word Frequency:
# {'board': 9, 'energy': 8, 'water': 19, 'management': 14, 'code': 13, 'district': 11, 'resource': 10, 'shall': 8, 'plan': 7, 'storm': 7, 'discharge': 7, 'http': 8, 'california': 7}
# --------------------------------------------------------------------------------
# Row 327 Word Frequency:
# {'water': 13, 'management': 11, 'board': 8, 'district': 12, 'superintendent': 7, 'designee': 7, 'shall': 9, 'plan': 7}
# --------------------------------------------------------------------------------
# Row 516 Word Frequency:
# {'energy': 9, 'water': 19, 'management': 15, 'board': 8, 'district': 12, 'resource': 9, 'superintendent': 7, 'designee': 7, 'shall': 9, 'plan': 7, 'storm': 7, 'discharge': 7, 'california': 7}
# --------------------------------------------------------------------------------
# Row 174 Word Frequency:
# {'district': 7}
# --------------------------------------------------------------------------------
# Row 555 Word Frequency:
# {'operation': 8, 'energy': 24, 'water': 13, 'district': 18, 'conservation': 10, 's': 10, 'help': 7, 'shall': 14, 'goal': 7, 'superintendent': 7, 'designee': 7, 'use': 8, 'http': 7}
# --------------------------------------------------------------------------------
# Row 242 Word Frequency:
# {'water': 13, 'management': 9, 'board': 8, 'district': 12, 'superintendent': 7, 'designee': 7, 'shall': 9}
# --------------------------------------------------------------------------------
# Row 612 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 11, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 207 Word Frequency:
# {'water': 11, 'management': 10, 'district': 12, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 172 Word Frequency:
# {'energy': 14, 'conservation': 11, 'district': 9}
# --------------------------------------------------------------------------------
# Row 475 Word Frequency:
# {'energy': 8, 'district': 10, 'shall': 8}
# --------------------------------------------------------------------------------
# Row 399 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 12, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 39 Word Frequency:
# {'energy': 7, 'district': 11}
# --------------------------------------------------------------------------------
# Row 290 Word Frequency:
# {'water': 8, 'management': 7, 'resource': 7, 'district': 9, 'code': 7}
# --------------------------------------------------------------------------------
# Row 15 Word Frequency:
# {}
# --------------------------------------------------------------------------------
# Row 345 Word Frequency:
# {'management': 7, 'district': 9, 'superintendent': 7, 'designee': 7, 'may': 7}
# --------------------------------------------------------------------------------
# Row 244 Word Frequency:
# {'energy': 15, 'water': 7, 'district': 11, 'help': 7, 'shall': 9}
# --------------------------------------------------------------------------------
# Row 97 Word Frequency:
# {'water': 13, 'management': 9, 'board': 8, 'district': 12, 'superintendent': 7, 'designee': 7, 'shall': 9}
# --------------------------------------------------------------------------------
# Row 605 Word Frequency:
# {'school': 12, 'district': 15, 'board': 9, 'energy': 8, 'water': 18, 'management': 15, 'resource': 12, 'goal': 7, 'superintendent': 9, 'designee': 9, 'shall': 12, 'use': 7, 'plan': 7, 'code': 8, 'emergency': 7, 'california': 9, 'http': 11}
# --------------------------------------------------------------------------------
# Row 534 Word Frequency:
# {'water': 14, 'management': 9, 'board': 8, 'district': 14, 'superintendent': 7, 'designee': 7, 'shall': 9}
# --------------------------------------------------------------------------------
# Row 215 Word Frequency:
# {'school': 11, 'district': 15, 'energy': 12, 'water': 22, 'management': 20, 'board': 7, 'resource': 11, 'superintendent': 9, 'designee': 9, 'shall': 11, 'use': 7, 'plan': 7, 'code': 8, 'emergency': 7, 'california': 9, 'http': 11}
# --------------------------------------------------------------------------------
# Row 535 Word Frequency:
# {'water': 14, 'management': 9, 'board': 8, 'district': 14, 'superintendent': 7, 'designee': 7, 'shall': 9}
# --------------------------------------------------------------------------------
# Row 610 Word Frequency:
# {'water': 13, 'management': 9, 'board': 8, 'district': 12, 'superintendent': 7, 'designee': 7, 'shall': 9}
# --------------------------------------------------------------------------------
# Row 310 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 12, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 538 Word Frequency:
# {'water': 13, 'management': 11, 'board': 8, 'district': 12, 'superintendentprincipal': 7, 'designee': 7, 'shall': 9, 'plan': 7}
# --------------------------------------------------------------------------------
# Row 114 Word Frequency:
# {'district': 7}
# --------------------------------------------------------------------------------
# Row 332 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 12, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 64 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 12, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 196 Word Frequency:
# {'water': 13, 'management': 11, 'board': 8, 'district': 12, 'superintendent': 7, 'designee': 7, 'shall': 9, 'plan': 7}
# --------------------------------------------------------------------------------
# Row 321 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 12, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 30 Word Frequency:
# {'water': 13, 'management': 11, 'board': 8, 'district': 12, 'superintendent': 7, 'designee': 7, 'shall': 9, 'plan': 7}
# --------------------------------------------------------------------------------
# Row 402 Word Frequency:
# {'water': 13, 'management': 11, 'board': 8, 'district': 12, 'superintendent': 7, 'designee': 7, 'shall': 9, 'plan': 7}
# --------------------------------------------------------------------------------
# Row 392 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 12, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 48 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 12, 'superintendentprincipal': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 449 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 12, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 544 Word Frequency:
# {'district': 7}
# --------------------------------------------------------------------------------
# Row 510 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 12, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 503 Word Frequency:
# {'water': 13, 'management': 9, 'board': 8, 'district': 12, 'superintendent': 7, 'designee': 7, 'shall': 9}
# --------------------------------------------------------------------------------
# Row 115 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 12, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 134 Word Frequency:
# {'water': 13, 'management': 9, 'board': 8, 'district': 12, 'superintendent': 7, 'designee': 7, 'shall': 9}
# --------------------------------------------------------------------------------
# Row 501 Word Frequency:
# {'management': 7, 'district': 10}
# --------------------------------------------------------------------------------
# Row 347 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 12, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 611 Word Frequency:
# {'water': 9, 'management': 9, 'district': 13, 'resource': 8, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 608 Word Frequency:
# {'district': 7}
# --------------------------------------------------------------------------------
# Row 163 Word Frequency:
# {'district': 7}
# --------------------------------------------------------------------------------
# Row 325 Word Frequency:
# {'water': 13, 'management': 9, 'board': 8, 'district': 12, 'superintendent': 7, 'designee': 7, 'shall': 9, 'storm': 7}
# --------------------------------------------------------------------------------
# Row 623 Word Frequency:
# {'water': 13, 'management': 9, 'board': 8, 'district': 12, 'superintendent': 7, 'designee': 7, 'shall': 9}
# --------------------------------------------------------------------------------
# Row 298 Word Frequency:
# {'water': 13, 'management': 9, 'board': 8, 'district': 12, 'superintendent': 7, 'designee': 7, 'shall': 9}
# --------------------------------------------------------------------------------
# Row 323 Word Frequency:
# {'water': 11, 'management': 10, 'district': 12, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 121 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 12, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 585 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 12, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 224 Word Frequency:
# {'district': 7}
# --------------------------------------------------------------------------------
# Row 573 Word Frequency:
# {'district': 7}
# --------------------------------------------------------------------------------
# Row 483 Word Frequency:
# {'energy': 9, 'district': 11, 'help': 7, 'shall': 10}
# --------------------------------------------------------------------------------
# Row 49 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 12, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 495 Word Frequency:
# {'water': 13, 'management': 9, 'board': 8, 'district': 12, 'superintendent': 7, 'designee': 7, 'shall': 9}
# --------------------------------------------------------------------------------
# Row 397 Word Frequency:
# {'energy': 9, 'water': 8, 'district': 14, 'help': 7, 'shall': 10}
# --------------------------------------------------------------------------------
# Row 309 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 12, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 572 Word Frequency:
# {'water': 13, 'management': 9, 'board': 8, 'district': 12, 'superintendentprincipal': 7, 'designee': 7, 'shall': 9}
# --------------------------------------------------------------------------------
# Row 546 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 12, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 316 Word Frequency:
# {'district': 7}
# --------------------------------------------------------------------------------
# Row 201 Word Frequency:
# {'whittier': 8, 'district': 19, 'energy': 20, 'water': 14, 'management': 23, 'board': 7, 'superintendent': 8, 'designee': 9, 'shall': 13, 'program': 10, 'conservation': 7}
# --------------------------------------------------------------------------------
# Row 388 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 12, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 223 Word Frequency:
# {'district': 7}
# --------------------------------------------------------------------------------
# Row 454 Word Frequency:
# {'energy': 16, 'district': 7}
# --------------------------------------------------------------------------------
# Row 133 Word Frequency:
# {'water': 13, 'management': 9, 'board': 8, 'district': 12, 'superintendentprincipal': 7, 'designee': 7, 'shall': 9}
# --------------------------------------------------------------------------------
# Row 338 Word Frequency:
# {'water': 11, 'management': 12, 'resource': 7, 'district': 13, 'goal': 7, 'superintendent': 9, 'designee': 9, 'shall': 12, 'plan': 7}
# --------------------------------------------------------------------------------
# Row 614 Word Frequency:
# {'energy': 11, 'water': 21, 'management': 11, 'code': 8, 'board': 12, 'district': 20, 'resource': 11, 'plan': 7, 'california': 8, 'storm': 10, 'control': 8, 'system': 7, 'http': 8}
# --------------------------------------------------------------------------------
# Row 615 Word Frequency:
# {'school': 12, 'district': 15, 'board': 9, 'energy': 8, 'water': 18, 'management': 15, 'resource': 12, 'goal': 7, 'superintendent': 9, 'designee': 9, 'shall': 12, 'use': 7, 'plan': 7, 'code': 8, 'emergency': 7, 'california': 9, 'http': 11}
# --------------------------------------------------------------------------------
# Row 148 Word Frequency:
# {'management': 7, 'district': 8}
# --------------------------------------------------------------------------------
# Row 149 Word Frequency:
# {'district': 7}
# --------------------------------------------------------------------------------
# Row 208 Word Frequency:
# {'district': 7}
# --------------------------------------------------------------------------------
# Row 375 Word Frequency:
# {'energy': 8, 'water': 19, 'management': 12, 'code': 7, 'board': 10, 'district': 11, 'resource': 8, 'superintendent': 7, 'designee': 7, 'storm': 8, 'shall': 8, 'discharge': 7, 'http': 8}
# --------------------------------------------------------------------------------
# Row 604 Word Frequency:
# {'water': 13, 'management': 11, 'board': 8, 'district': 12, 'superintendent': 7, 'designee': 7, 'shall': 9, 'plan': 7}
# --------------------------------------------------------------------------------
# Row 94 Word Frequency:
# {'energy': 7, 'water': 16, 'management': 11, 'resource': 8, 'district': 11, 'superintendent': 9, 'designee': 9, 'shall': 12, 'code': 8}
# --------------------------------------------------------------------------------
# Row 429 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 12, 'superintendent': 9, 'designee': 9, 'shall': 11}
# --------------------------------------------------------------------------------
# Row 427 Word Frequency:
# {'energy': 24, 'water': 19, 'management': 11, 'board': 10, 'resource': 8, 'student': 7, 'district': 18, 'goal': 9, 'superintendent': 10, 'designee': 12, 'shall': 18, 'program': 9, 'use': 10, 'conservation': 7}
# --------------------------------------------------------------------------------
# Row 251 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 12, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 468 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 12, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 288 Word Frequency:
# {'water': 12, 'management': 10, 'board': 8, 'resource': 8, 'district': 13, 'superintendent': 9, 'designee': 9, 'shall': 11}
# --------------------------------------------------------------------------------
# Row 194 Word Frequency:
# {'district': 7}
# --------------------------------------------------------------------------------
# Row 255 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 12, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 385 Word Frequency:
# {'water': 12, 'management': 8, 'board': 8, 'district': 12, 'shall': 8}
# --------------------------------------------------------------------------------
# Row 342 Word Frequency:
# {'district': 7}
# --------------------------------------------------------------------------------
# Row 314 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 12, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 393 Word Frequency:
# {'energy': 10, 'water': 20, 'management': 15, 'resource': 11, 'district': 12, 'superintendent': 9, 'designee': 9, 'shall': 12, 'code': 8, 'school': 7, 'california': 10, 'http': 11}
# --------------------------------------------------------------------------------
# Row 380 Word Frequency:
# {'water': 11, 'management': 10, 'district': 12, 'superintendent': 9, 'designee': 9, 'shall': 11}
# --------------------------------------------------------------------------------
# Row 1 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 12, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 184 Word Frequency:
# {'water': 13, 'management': 9, 'board': 8, 'district': 12, 'superintendent': 7, 'designee': 7, 'shall': 9}
# --------------------------------------------------------------------------------
# Row 447 Word Frequency:
# {'water': 13, 'management': 9, 'board': 8, 'district': 12, 'superintendentprincipal': 7, 'designee': 7, 'shall': 9}
# --------------------------------------------------------------------------------
# Row 558 Word Frequency:
# {'district': 7}
# --------------------------------------------------------------------------------
# Row 559 Word Frequency:
# {'district': 7}
# --------------------------------------------------------------------------------
# Row 571 Word Frequency:
# {'energy': 8, 'water': 7, 'management': 9, 'district': 7, 'resource': 8, 'california': 7}
# --------------------------------------------------------------------------------
# Row 574 Word Frequency:
# {'district': 7}
# --------------------------------------------------------------------------------
# Row 592 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 11, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 157 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 12, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 92 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 12, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 446 Word Frequency:
# {'water': 13, 'management': 9, 'board': 8, 'district': 12, 'superintendent': 7, 'designee': 7, 'shall': 9}
# --------------------------------------------------------------------------------
# Row 122 Word Frequency:
# {'water': 13, 'management': 11, 'board': 8, 'district': 12, 'superintendent': 7, 'designee': 7, 'shall': 9, 'plan': 7}
# --------------------------------------------------------------------------------
# Row 2 Word Frequency:
# {'management': 7, 'district': 9, 'superintendent': 7, 'designee': 7, 'shall': 7}
# --------------------------------------------------------------------------------
# Row 417 Word Frequency:
# {'energy': 12, 'water': 34, 'management': 21, 'joint': 7, 'california': 18, 'board': 12, 'resource': 15, 'district': 24, 's': 8, 'use': 11, 'goal': 7, 'superintendent': 10, 'designee': 9, 'shall': 12, 'may': 9, 'practice': 9, 'school': 13, 'education': 7, 'plan': 17, 'storm': 11, 'state': 9, 'discharge': 10, 'general': 9, 'permit': 11, 'control': 11, 'department': 7, 'code': 10, 'emergency': 15, 'http': 11}
# --------------------------------------------------------------------------------
# Row 618 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 12, 'superintendent': 8, 'designee': 8, 'shall': 10}
# --------------------------------------------------------------------------------
# Row 415 Word Frequency:
# {'water': 13, 'management': 9, 'board': 8, 'district': 12, 'superintendentprincipal': 7, 'designee': 7, 'shall': 9}
# --------------------------------------------------------------------------------
# Row 25 Word Frequency:
# {'district': 7}
# --------------------------------------------------------------------------------
# Row 113 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 13, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 93 Word Frequency:
# {'water': 13, 'management': 9, 'board': 8, 'district': 12, 'superintendent': 7, 'designee': 7, 'shall': 9}
# --------------------------------------------------------------------------------
# Row 376 Word Frequency:
# {'water': 11, 'management': 8, 'district': 9, 'shall': 10}
# --------------------------------------------------------------------------------
# Row 225 Word Frequency:
# {'water': 13, 'management': 9, 'board': 8, 'district': 12, 'superintendent': 7, 'designee': 7, 'shall': 9}
# --------------------------------------------------------------------------------
# Row 108 Word Frequency:
# {'district': 7}
# --------------------------------------------------------------------------------
# Row 500 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 12, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 526 Word Frequency:
# {'water': 13, 'management': 9, 'board': 8, 'district': 12, 'superintendentprincipal': 7, 'designee': 7, 'shall': 9}
# --------------------------------------------------------------------------------
# Row 104 Word Frequency:
# {'district': 7}
# --------------------------------------------------------------------------------
# Row 187 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 12, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 479 Word Frequency:
# {'district': 7, 'energy': 9}
# --------------------------------------------------------------------------------
# Row 87 Word Frequency:
# {'water': 13, 'management': 11, 'board': 8, 'district': 12, 'superintendent': 7, 'designee': 7, 'shall': 9, 'plan': 7}
# --------------------------------------------------------------------------------
# Row 548 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 12, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 435 Word Frequency:
# {'water': 8, 'management': 9, 'district': 9, 'shall': 8}
# --------------------------------------------------------------------------------
# Row 550 Word Frequency:
# {'district': 10, 'energy': 15, 'conservation': 10}
# --------------------------------------------------------------------------------
# Row 398 Word Frequency:
# {'water': 11, 'management': 10, 'district': 12, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 300 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 12, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 197 Word Frequency:
# {'district': 7}
# --------------------------------------------------------------------------------
# Row 162 Word Frequency:
# {'district': 7}
# --------------------------------------------------------------------------------
# Row 161 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 12, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 423 Word Frequency:
# {'water': 13, 'management': 9, 'board': 8, 'district': 12, 'superintendent': 7, 'designee': 7, 'shall': 9}
# --------------------------------------------------------------------------------
# Row 603 Word Frequency:
# {'district': 7}
# --------------------------------------------------------------------------------
# Row 329 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 12, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 426 Word Frequency:
# {'district': 7}
# --------------------------------------------------------------------------------
# Row 31 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 12, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 111 Word Frequency:
# {'water': 13, 'management': 9, 'board': 8, 'district': 12, 'superintendent': 7, 'designee': 7, 'shall': 9}
# --------------------------------------------------------------------------------
# Row 256 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 12, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 563 Word Frequency:
# {'water': 13, 'management': 9, 'board': 8, 'district': 12, 'superintendentprincipal': 7, 'designee': 7, 'shall': 9}
# --------------------------------------------------------------------------------
# Row 53 Word Frequency:
# {'energy': 8, 'water': 7, 'management': 9, 'district': 7, 'resource': 8, 'california': 7}
# --------------------------------------------------------------------------------
# Row 73 Word Frequency:
# {'water': 13, 'management': 9, 'board': 8, 'district': 12, 'superintendent': 7, 'designee': 7, 'shall': 9}
# --------------------------------------------------------------------------------
# Row 252 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 12, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 271 Word Frequency:
# {'energy': 8, 'water': 18, 'management': 15, 'board': 7, 'resource': 12, 'district': 13, 'goal': 7, 'superintendent': 9, 'designee': 9, 'shall': 12, 'use': 7, 'school': 10, 'plan': 7, 'code': 8, 'emergency': 7, 'california': 9, 'http': 11}
# --------------------------------------------------------------------------------
# Row 277 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 12, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 272 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 12, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 624 Word Frequency:
# {'water': 13, 'management': 9, 'board': 8, 'district': 12, 'superintendent': 7, 'designee': 7, 'shall': 9}
# --------------------------------------------------------------------------------
# Row 109 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 12, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 517 Word Frequency:
# {'energy': 12, 'management': 7, 'district': 20, 'natural': 7, 'resource': 13, 'conservation': 10, 'school': 11}
# --------------------------------------------------------------------------------
# Row 350 Word Frequency:
# {'district': 7}
# --------------------------------------------------------------------------------
# Row 214 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 12, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 395 Word Frequency:
# {'district': 7}
# --------------------------------------------------------------------------------
# Row 191 Word Frequency:
# ...
# Row 391 Word Frequency:
# {'school': 7, 'district': 12, 'energy': 8, 'water': 19, 'management': 14, 'board': 8, 'resource': 12, 'superintendent': 9, 'designee': 9, 'shall': 12, 'code': 7, 'california': 8, 'http': 11}
# --------------------------------------------------------------------------------
# Row 24 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 12, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 394 Word Frequency:
# {'water': 14, 'management': 10, 'board': 8, 'district': 12, 'superintendent': 7, 'designee': 7, 'storm': 7, 'plan': 7}
# --------------------------------------------------------------------------------
# Row 181 Word Frequency:
# {'water': 11, 'management': 9, 'district': 10, 'superintendent': 7, 'designee': 7, 'shall': 11}
# --------------------------------------------------------------------------------
# Row 179 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 12, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 602 Word Frequency:
# {'water': 11, 'management': 12, 'resource': 7, 'district': 13, 'goal': 7, 'superintendent': 9, 'designee': 9, 'shall': 12, 'plan': 7}
# --------------------------------------------------------------------------------
# Row 168 Word Frequency:
# {'water': 13, 'management': 9, 'board': 8, 'district': 12, 'superintendent': 7, 'designee': 7, 'shall': 9}
# --------------------------------------------------------------------------------
# Row 601 Word Frequency:
# {'water': 11, 'management': 12, 'resource': 7, 'district': 13, 'goal': 7, 'superintendent': 9, 'designee': 9, 'shall': 12, 'plan': 7}
# --------------------------------------------------------------------------------
# Row 403 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 12, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 404 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 12, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 600 Word Frequency:
# {'water': 11, 'management': 12, 'resource': 7, 'district': 13, 'goal': 7, 'superintendent': 9, 'designee': 9, 'shall': 12, 'plan': 7}
# --------------------------------------------------------------------------------
# Row 599 Word Frequency:
# {'energy': 10, 'water': 20, 'management': 17, 'resource': 12, 'district': 13, 'goal': 7, 'superintendent': 9, 'designee': 9, 'shall': 12, 'use': 7, 'school': 10, 'plan': 7, 'code': 8, 'emergency': 7, 'california': 10, 'http': 11}
# --------------------------------------------------------------------------------
# Row 412 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 12, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 177 Word Frequency:
# {'district': 7}
# --------------------------------------------------------------------------------
# Row 547 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 12, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 62 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 12, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 58 Word Frequency:
# {}
# --------------------------------------------------------------------------------
# Row 304 Word Frequency:
# {'water': 9, 'management': 10, 'district': 11, 'superintendent': 8, 'designee': 8, 'shall': 11}
# --------------------------------------------------------------------------------
# Row 150 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 12, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 178 Word Frequency:
# {'management': 7, 'district': 9}
# --------------------------------------------------------------------------------
# Row 188 Word Frequency:
# {'water': 11, 'management': 12, 'resource': 7, 'district': 13, 'goal': 7, 'superintendent': 9, 'designee': 9, 'shall': 12, 'plan': 7}
# --------------------------------------------------------------------------------
# Row 364 Word Frequency:
# {'management': 7, 'district': 9}
# --------------------------------------------------------------------------------
# Row 259 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 12, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 142 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 12, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 448 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 12, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 421 Word Frequency:
# {'energy': 10, 'water': 18, 'management': 17, 'resource': 12, 'district': 12, 'goal': 7, 'superintendent': 9, 'designee': 9, 'shall': 12, 'use': 7, 'school': 9, 'plan': 7, 'code': 8, 'emergency': 7, 'california': 9, 'http': 11}
# --------------------------------------------------------------------------------
# Row 471 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 11, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 118 Word Frequency:
# {'water': 10, 'district': 9, 'shall': 8}
# --------------------------------------------------------------------------------
# Row 484 Word Frequency:
# {'water': 10, 'management': 7, 'district': 9}
# --------------------------------------------------------------------------------
# Row 275 Word Frequency:
# {'school': 13, 'district': 16, 'superintendent': 13, '530': 8, 'board': 7, 'energy': 8, 'water': 18, 'management': 15, 'resource': 12, 'goal': 7, 'designee': 9, 'shall': 12, 'use': 7, 'plan': 7, 'code': 8, 'emergency': 7, 'california': 9, 'http': 11}
# --------------------------------------------------------------------------------
# Row 409 Word Frequency:
# {'water': 11, 'resource': 7, 'district': 12, 'management': 10, 'designee': 9, 'shall': 12, 'superintendentprincipal': 8}
# --------------------------------------------------------------------------------
# Row 85 Word Frequency:
# {}
# --------------------------------------------------------------------------------
# Row 302 Word Frequency:
# {'water': 12, 'management': 11, 'resource': 7, 'district': 12, 'superintendent': 9, 'designee': 9, 'may': 8, 'shall': 9}
# --------------------------------------------------------------------------------
# Row 106 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 12, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 99 Word Frequency:
# {'water': 10, 'management': 8, 'resource': 7, 'district': 11, 'superintendentprincipal': 8, 'designee': 8, 'shall': 9}
# --------------------------------------------------------------------------------
# Row 212 Word Frequency:
# {'energy': 7, 'shall': 7, 'district': 7}
# --------------------------------------------------------------------------------
# Row 554 Word Frequency:
# {'energy': 9, 'district': 11, 'help': 7, 'shall': 10}
# --------------------------------------------------------------------------------
# Row 100 Word Frequency:
# {'district': 7}
# --------------------------------------------------------------------------------
# Row 102 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 12, 'superintendentprincipal': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 487 Word Frequency:
# {}
# --------------------------------------------------------------------------------
# Row 613 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 12, 'superintendent': 8, 'designee': 8, 'shall': 10}
# --------------------------------------------------------------------------------
# Row 285 Word Frequency:
# {'energy': 7, 'water': 16, 'management': 10, 'code': 8, 'resource': 7, 'district': 10, 'superintendent': 7, 'designee': 7, 'shall': 9}
# --------------------------------------------------------------------------------
# Row 477 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 12, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 38 Word Frequency:
# {'energy': 12, 'water': 8, 'management': 7, 'district': 11, 'shall': 8, 'conservation': 8}
# --------------------------------------------------------------------------------
# Row 299 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 12, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 10 Word Frequency:
# {'water': 12, 'management': 10, 'resource': 7, 'district': 13, 'goal': 7, 'superintendent': 10, 'designee': 10, 'shall': 13}
# --------------------------------------------------------------------------------
# Row 362 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 12, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 328 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 11, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 312 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 12, 'superintendentprincipal': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 180 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 12, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 262 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 11, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 136 Word Frequency:
# {}
# --------------------------------------------------------------------------------
# Row 445 Word Frequency:
# {'energy': 9, 'district': 11, 'help': 7, 'shall': 10}
# --------------------------------------------------------------------------------
# Row 578 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 12, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 32 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 12, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 41 Word Frequency:
# {'energy': 23, 'management': 10, 'program': 7}
# --------------------------------------------------------------------------------
# Row 414 Word Frequency:
# {}
# --------------------------------------------------------------------------------
# Row 528 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 12, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 490 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 11, 'superintendentprincipal': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 117 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 12, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 296 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 12, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 128 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 12, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 278 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 12, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 129 Word Frequency:
# {}
# --------------------------------------------------------------------------------
# Row 131 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 12, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 457 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 12, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 176 Word Frequency:
# {'water': 12, 'management': 11, 'resource': 7, 'district': 12, 'superintendentprincipal': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 141 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 12, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 33 Word Frequency:
# {'district': 13, 'natural': 25, 'resource': 25, 'conservation': 7, 'program': 8, 'shall': 10}
# --------------------------------------------------------------------------------
# Row 245 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 12, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 206 Word Frequency:
# {'energy': 9, 'district': 11, 'help': 7, 'shall': 10}
# --------------------------------------------------------------------------------
# Row 71 Word Frequency:
# {'school': 10, 'district': 13, 'board': 9, 'energy': 8, 'water': 18, 'management': 15, 'resource': 12, 'goal': 7, 'superintendent': 9, 'designee': 9, 'shall': 12, 'use': 7, 'plan': 7, 'code': 8, 'emergency': 7, 'california': 9, 'http': 11}
# --------------------------------------------------------------------------------
# Row 431 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 12, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 401 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 12, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 334 Word Frequency:
# {'energy': 9}
# --------------------------------------------------------------------------------
# Row 84 Word Frequency:
# {'water': 11, 'management': 10, 'resource': 7, 'district': 11, 'superintendent': 9, 'designee': 9, 'shall': 12}
# --------------------------------------------------------------------------------
# Row 143 Word Frequency:
# {'school': 10, 'district': 16, 'energy': 8, 'water': 17, 'management': 18, 'board': 7, 'environmental': 7, 'resource': 11, 'goal': 7, 'superintendent': 9, 'designee': 9, 'shall': 12, 'use': 7, 'plan': 9, 'code': 11, 'emergency': 8, 'california': 10, 'website': 12}
# --------------------------------------------------------------------------------

# %%
# Aggregate word frequencies across all rows
aggregate_frequency = Counter()
for freq in data['word_frequency']:
    aggregate_frequency.update(freq)

# Filter out low-frequency and irrelevant words
filtered_aggregate_frequency = {word: count for word, count in aggregate_frequency.items() if count > 6 and word not in ['cf', 's']}

# Display the top 20 most frequent words
print("Top 20 Frequent Words Across All Policies:")
Counter(filtered_aggregate_frequency).most_common(20)
# Out:
# Top 20 Frequent Words Across All Policies:
# [('district', 6250),
#  ('water', 5653),
#  ('shall', 5284),
#  ('management', 5060),
#  ('designee', 4084),
#  ('superintendent', 3809),
#  ('resource', 3567),
#  ('energy', 3221),
#  ('board', 2900),
#  ('goal', 2806),
#  ('program', 2585),
#  ('conservation', 2407),
#  ('plan', 2095),
#  ('may', 1947),
#  ('storm', 1872),
#  ('use', 1796),
#  ('practice', 1521),
#  ('student', 1448),
#  ('staff', 1369),
#  ('develop', 1273)]

# %%
# Get the top 20 frequent words
top_words = Counter(filtered_aggregate_frequency).most_common(20)
words, counts = zip(*top_words)

# Create a bar chart
plt.figure(figsize=(12, 6))
plt.bar(words, counts, color='skyblue', edgecolor='black')
plt.xlabel('Words', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.title('Top 20 Most Frequent Words Across School District Board Policies', fontsize=14)
plt.xticks(rotation=45)
plt.tight_layout()

# Show the plot
plt.show()

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(filtered_words)
plt.figure(figsize=(10,5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Frequency Word Cloud')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Indicator Analysis

# %% [markdown]
# ### Energy Efficiency

# %%
# Calculate the total number of 0s and 1s in the Energy Efficiency column
energy_efficiency_counts = data['Energy Efficiency'].value_counts()

# Display the counts
print("Counts in the 'Energy Efficiency' column:")
print(energy_efficiency_counts)
# Out:
# Counts in the 'Energy Efficiency' column:
# Energy Efficiency
# 0    295
# 1    278
# Name: count, dtype: int64

# %%
# List of keywords to filter for Energy Efficiency Indicator 
keywords = ['school energy conservation programs', 'energy-saving initiatives', 'energy efficiency']

# Filter policies containing any of the keywords
policies_with_keywords_in_text = data[data["BP3511: PDF Text"].apply(
    lambda text: any(keyword in str(text).lower() for keyword in keywords)
)]

# Count the number of policies containing the keywords
keyword_count = len(policies_with_keywords_in_text)

# Display the count
print(f"Number of policies containing the keyword(s) {keywords}: {keyword_count}")

# Calculate the total number of 0s and 1s in the Energy Efficiency column
efficiency_counts = policies_with_keywords_in_text['Energy Efficiency'].value_counts()

# Display the total counts
print("\nTotal counts in the 'Energy Efficiency' column:")
print(efficiency_counts)

# Display which keywords were found and their counts
keyword_found_counts = {keyword: policies_with_keywords_in_text["BP3511: PDF Text"].apply(
    lambda text: str(text).lower().count(keyword)
).sum() for keyword in keywords}

print("\nKeyword occurrences:")
for keyword, count in keyword_found_counts.items():
    print(f"'{keyword}': {count}")

# Display the relevant rows
print(f"\nPolicies containing any of the words {keywords}:")
policies_with_keywords_in_text[['District Name', 'BP3511: PDF Text', 'Energy Efficiency']]
# Out:
# Number of policies containing the keyword(s) ['school energy conservation programs', 'energy-saving initiatives', 'energy efficiency']: 28
#
# Total counts in the 'Energy Efficiency' column:
# Energy Efficiency
# 1    16
# 0    12
# Name: count, dtype: int64
#
# Keyword occurrences:
# 'school energy conservation programs': 0
# 'energy-saving initiatives': 0
# 'energy efficiency': 47
#
# Policies containing any of the words ['school energy conservation programs', 'energy-saving initiatives', 'energy efficiency']:
#                     District Name  \
# 51                 Clovis Unified
# 291             Santa Ana Unified
# 44      Gold Oak Union Elementary
# 53                 Fresno Unified
# 364         Silver Valley Unified
# 122                     Taft City
# 380          Grossmont Union High
# 43           El Dorado Union High
# 204         Walnut Valley Unified
# 184              Monrovia Unified
# 350           Etiwanda Elementary
# 6                 Oakland Unified
# 554       Sylvan Union Elementary
# 474              San Jose Unified
# 38       San Ramon Valley Unified
# 243             Merced Union High
# 482         Pajaro Valley Unified
# 396         Sweetwater Union High
# 453  Santa Maria Joint Union High
# 426              Cabrillo Unified
# 124             Tehachapi Unified
# 621        Woodland Joint Unified
# 211         Chowchilla Elementary
# 553       Patterson Joint Unified
# 37              Pittsburg Unified
# 444     Buellton Union Elementary
# 40       Del Norte County Unified
# 205      Acton-Agua Dulce Unified
#
#                                       BP3511: PDF Text  Energy Efficiency
# 51   board policy 3511 clovis unified school distri...                  1
# 291  santa ana unified school district board policy...                  1
# 44   business noninstructional operation bp 3511 en...                  0
# 53   fresno usd 3000 bp 3511 business noninstructio...                  0
# 364  business noninstructional operation bp 3511 en...                  1
# 122  book board policy section 3000 business nonins...                  1
# 380  book board policy manual section 3000 business...                  1
# 43   policy 3511 energy water management status ado...                  1
# 204  business noninstructional operation bp 3511 en...                  1
# 184  monrovia unified school district board policy ...                  1
# 350  etiwanda school district board policy 3511 ene...                  0
# 6    oakland unified school district board policy b...                  1
# 554  book board policy section 3000 business nonins...                  0
# 474  policy 3511 energy water management status ado...                  0
# 38   policy 3511 energy water management status ado...                  1
# 243  book muhsd policy section 3000 business nonins...                  1
# 482  policy 3511 energy water management status ado...                  0
# 396  policy 3511 energy water management status ado...                  1
# 453  policy 3511 energy water management status ado...                  0
# 426  policy 3511 energy water management status ado...                  1
# 124  policy 3511 energy water management status ado...                  0
# 621  policy 3511 energy water management status ado...                  0
# 211  policy 3511 energy water management policy 351...                  1
# 553  policy 3511 energy water management status ado...                  0
# 37   policy 3511 energy water management status ado...                  1
# 444  policy 3511 energy water management status ado...                  0
# 40   policy 3511 energy water management status ado...                  1
# 205  policy 3511 energy water management status ado...                  0

# %% [markdown]
# ### On-Site Renewables

# %%
# Calculate the total number of 0s and 1s in the On-Site Renewables column
onsite_renewables_counts = data['On-Site Renewables'].value_counts()

# Display the counts
print("Counts in the 'On-Site Renewables' column:")
print(onsite_renewables_counts)
# Out:
# Counts in the 'On-Site Renewables' column:
# On-Site Renewables
# 0    335
# 1    238
# Name: count, dtype: int64

# %%
# List of keywords to filter for On-Site Renewables Indicator 
keywords = ['on-site renewable energy', 'solar power', 'wind energy', 'renewable energy']

# Filter policies containing any of the keywords
policies_with_keywords_in_text = data[data["BP3511: PDF Text"].apply(
    lambda text: any(keyword in str(text).lower() for keyword in keywords)
)]

# Count the number of policies containing the keywords
keyword_count = len(policies_with_keywords_in_text)

# Display the count
print(f"Number of policies containing the keyword(s) {keywords}: {keyword_count}")

# Calculate the total number of 0s and 1s in the Energy Efficiency column
efficiency_counts = policies_with_keywords_in_text['On-Site Renewables'].value_counts()

# Display the total counts
print("\nTotal counts in the 'On-Site Renewables' column:")
print(efficiency_counts)

# Display which keywords were found and their counts
keyword_found_counts = {keyword: policies_with_keywords_in_text["BP3511: PDF Text"].apply(
    lambda text: str(text).lower().count(keyword)
).sum() for keyword in keywords}

print("\nKeyword occurrences:")
for keyword, count in keyword_found_counts.items():
    print(f"'{keyword}': {count}")

# Display the relevant rows
print(f"\nPolicies containing any of the words {keywords}:")
policies_with_keywords_in_text[['District Name', 'BP3511: PDF Text', 'On-Site Renewables']]
# Out:
# Number of policies containing the keyword(s) ['on-site renewable energy', 'solar power', 'wind energy', 'renewable energy']: 4
#
# Total counts in the 'On-Site Renewables' column:
# On-Site Renewables
# 0    2
# 1    2
# Name: count, dtype: int64
#
# Keyword occurrences:
# 'on-site renewable energy': 0
# 'solar power': 2
# 'wind energy': 0
# 'renewable energy': 4
#
# Policies containing any of the words ['on-site renewable energy', 'solar power', 'wind energy', 'renewable energy']:
#                District Name  \
# 533    Santa Rosa Elementary
# 534          Santa Rosa High
# 426         Cabrillo Unified
# 333  Sacramento City Unified
#
#                                       BP3511: PDF Text  On-Site Renewables
# 533  policy 3511 energy water management status ado...                   0
# 534  policy 3511 energy water management status ado...                   0
# 426  policy 3511 energy water management status ado...                   1
# 333  policy 3511 energy water management status ado...                   1

# %% [markdown]
# ### HVAC: AC

# %%
# Calculate the total number of 0s and 1s in the HVAC: AC column
HVAC_AC_counts = data['HVAC: AC'].value_counts()

# Display the counts
print("Counts in the 'HVAC: AC' column:")
print(HVAC_AC_counts)
# Out:
# Counts in the 'HVAC: AC' column:
# HVAC: AC
# 1.0    343
# 0.0    204
# Name: count, dtype: int64

# %%
# List of keywords to filter for HVAC: AC Indicator 
keywords = ['HVAC systems', 'air conditioning upgrades', 'energy efficient HVAC school buildings', 'HVAC', 'air conditioning']

# Filter policies containing any of the keywords
policies_with_keywords_in_text = data[data["BP3511: PDF Text"].apply(
    lambda text: any(keyword in str(text).lower() for keyword in keywords)
)]

# Count the number of policies containing the keywords
keyword_count = len(policies_with_keywords_in_text)

# Display the count
print(f"Number of policies containing the keyword(s) {keywords}: {keyword_count}")

# Calculate the total number of 0s and 1s in the Energy Efficiency column
efficiency_counts = policies_with_keywords_in_text['HVAC: AC'].value_counts()

# Display the total counts
print("\nTotal counts in the 'HVAC: AC' column:")
print(efficiency_counts)

# Display which keywords were found and their counts
keyword_found_counts = {keyword: policies_with_keywords_in_text["BP3511: PDF Text"].apply(
    lambda text: str(text).lower().count(keyword)
).sum() for keyword in keywords}

print("\nKeyword occurrences:")
for keyword, count in keyword_found_counts.items():
    print(f"'{keyword}': {count}")

# Display the relevant rows
print(f"\nPolicies containing any of the words {keywords}:")
policies_with_keywords_in_text[['District Name', 'BP3511: PDF Text', 'HVAC: AC']]
# Out:
# Number of policies containing the keyword(s) ['HVAC systems', 'air conditioning upgrades', 'energy efficient HVAC school buildings', 'HVAC', 'air conditioning']: 8
#
# Total counts in the 'HVAC: AC' column:
# HVAC: AC
# 1.0    5
# 0.0    3
# Name: count, dtype: int64
#
# Keyword occurrences:
# 'HVAC systems': 0
# 'air conditioning upgrades': 0
# 'energy efficient HVAC school buildings': 0
# 'HVAC': 0
# 'air conditioning': 9
#
# Policies containing any of the words ['HVAC systems', 'air conditioning upgrades', 'energy efficient HVAC school buildings', 'HVAC', 'air conditioning']:
#                   District Name  \
# 217       Larkspur-Corte Madera
# 200         Whittier Union High
# 516        Vallejo City Unified
# 181         Los Angeles Unified
# 77   Cuddeback Union Elementary
# 490         Columbia Elementary
# 359    Rim of the World Unified
# 40     Del Norte County Unified
#
#                                       BP3511: PDF Text  HVAC: AC
# 217  business noninstructional operation bp 3511 en...       1.0
# 200  1 whittier union high school district whittier...       1.0
# 516  policy 3511 energy water management status ado...       0.0
# 181  los angeles unified school district policy bul...       1.0
# 77   business noninstructional operation bp 3511 en...       1.0
# 490  business noninstructional operation bp 3511 en...       0.0
# 359  regulation 3511 energy water management regula...       0.0
# 40   policy 3511 energy water management status ado...       1.0

# %% [markdown]
# ### Indoor Air Quality

# %%
# Calculate the total number of 0s and 1s in the Indoor Air Quality column
indoor_air_quality_counts = data['Indoor Air Quality'].value_counts()

# Display the counts
print("Counts in the 'Indoor Air Quality' column:")
print(indoor_air_quality_counts)
# Out:
# Counts in the 'Indoor Air Quality' column:
# Indoor Air Quality
# 0.0    290
# 1.0    256
# Name: count, dtype: int64

# %%
# List of keywords to filter for Indoor Air Quality Indicator 
keywords = ['indoor air quality', 'air filtration systems', 'air filtration', 'healthy air school initiative', 'air quality', 'IEQ', 'IEQ (Indoor Environmental Quality) Initiative']

# Filter policies containing any of the keywords
policies_with_keywords_in_text = data[data["BP3511: PDF Text"].apply(
    lambda text: any(keyword in str(text).lower() for keyword in keywords)
)]

# Count the number of policies containing the keywords
keyword_count = len(policies_with_keywords_in_text)

# Display the count
print(f"Number of policies containing the keyword(s) {keywords}: {keyword_count}")

# Calculate the total number of 0s and 1s in the Energy Efficiency column
efficiency_counts = policies_with_keywords_in_text['Indoor Air Quality'].value_counts()

# Display the total counts
print("\nTotal counts in the 'Indoor Air Quality' column:")
print(efficiency_counts)

# Display which keywords were found and their counts
keyword_found_counts = {keyword: policies_with_keywords_in_text["BP3511: PDF Text"].apply(
    lambda text: str(text).lower().count(keyword)
).sum() for keyword in keywords}

print("\nKeyword occurrences:")
for keyword, count in keyword_found_counts.items():
    print(f"'{keyword}': {count}")

# Display the relevant rows
print(f"\nPolicies containing any of the words {keywords}:")
policies_with_keywords_in_text[['District Name', 'BP3511: PDF Text', 'Indoor Air Quality']]
# Out:
# Number of policies containing the keyword(s) ['indoor air quality', 'air filtration systems', 'air filtration', 'healthy air school initiative', 'air quality', 'IEQ', 'IEQ (Indoor Environmental Quality) Initiative']: 1
#
# Total counts in the 'Indoor Air Quality' column:
# Indoor Air Quality
# 1.0    1
# Name: count, dtype: int64
#
# Keyword occurrences:
# 'indoor air quality': 1
# 'air filtration systems': 0
# 'air filtration': 0
# 'healthy air school initiative': 0
# 'air quality': 1
# 'IEQ': 0
# 'IEQ (Indoor Environmental Quality) Initiative': 0
#
# Policies containing any of the words ['indoor air quality', 'air filtration systems', 'air filtration', 'healthy air school initiative', 'air quality', 'IEQ', 'IEQ (Indoor Environmental Quality) Initiative']:
#                District Name  \
# 228  Mariposa County Unified
#
#                                       BP3511: PDF Text  Indoor Air Quality
# 228  book board policy section 3000 business nonins...                 1.0

# %% [markdown]
# ### Energy Resilience

# %%
# Calculate the total number of 0s and 1s in the Energy Resilience column
energy_resilience_counts = data['Energy Resilience'].value_counts()

# Display the counts
print("Counts in the 'Energy Resilience' column:")
print(energy_resilience_counts)
# Out:
# Counts in the 'Energy Resilience' column:
# Energy Resilience
# 0    405
# 1    168
# Name: count, dtype: int64

# %%
# List of keywords to filter for Energy Resilience Indicator 
keywords = ['energy resilience', 'energy backup', 'renewable energy storage', 'renewable energy', 'energy storage']

# Filter policies containing any of the keywords
policies_with_keywords_in_text = data[data["BP3511: PDF Text"].apply(
    lambda text: any(keyword in str(text).lower() for keyword in keywords)
)]

# Count the number of policies containing the keywords
keyword_count = len(policies_with_keywords_in_text)

# Display the count
print(f"Number of policies containing the keyword(s) {keywords}: {keyword_count}")

# Calculate the total number of 0s and 1s in the Energy Efficiency column
efficiency_counts = policies_with_keywords_in_text['Energy Resilience'].value_counts()

# Display the total counts
print("\nTotal counts in the 'Energy Resilience' column:")
print(efficiency_counts)

# Display which keywords were found and their counts
keyword_found_counts = {keyword: policies_with_keywords_in_text["BP3511: PDF Text"].apply(
    lambda text: str(text).lower().count(keyword)
).sum() for keyword in keywords}

print("\nKeyword occurrences:")
for keyword, count in keyword_found_counts.items():
    print(f"'{keyword}': {count}")

# Display the relevant rows
print(f"\nPolicies containing any of the words {keywords}:")
policies_with_keywords_in_text[['District Name', 'BP3511: PDF Text', 'Energy Resilience']]
# Out:
# Number of policies containing the keyword(s) ['energy resilience', 'energy backup', 'renewable energy storage', 'renewable energy', 'energy storage']: 2
#
# Total counts in the 'Energy Resilience' column:
# Energy Resilience
# 0    1
# 1    1
# Name: count, dtype: int64
#
# Keyword occurrences:
# 'energy resilience': 0
# 'energy backup': 0
# 'renewable energy storage': 0
# 'renewable energy': 4
# 'energy storage': 0
#
# Policies containing any of the words ['energy resilience', 'energy backup', 'renewable energy storage', 'renewable energy', 'energy storage']:
#                District Name  \
# 426         Cabrillo Unified
# 333  Sacramento City Unified
#
#                                       BP3511: PDF Text  Energy Resilience
# 426  policy 3511 energy water management status ado...                  0
# 333  policy 3511 energy water management status ado...                  1

# %% [markdown]
# ### Fleet Electrification

# %%
# Calculate the total number of 0s and 1s in the EV Chargers for Fleet Electrification column
fleet_electrification_counts = data['Fleet Electrification'].value_counts()

# Display the counts
print("Counts in the 'Fleet Electrification' column:")
print(fleet_electrification_counts)
# Out:
# Counts in the 'Fleet Electrification' column:
# Fleet Electrification
# 0.0    470
# 1.0    102
# Name: count, dtype: int64

# %%
# List of keywords to filter for Fleet Electrification Indicator 
keywords = ['electric school buses', 'fleet electrification schools', 'school district EV fleet', 'electric school bus', 'electric vehicle']

# Filter policies containing any of the keywords
policies_with_keywords_in_text = data[data["BP3511: PDF Text"].apply(
    lambda text: any(keyword in str(text).lower() for keyword in keywords)
)]

# Count the number of policies containing the keywords
keyword_count = len(policies_with_keywords_in_text)

# Display the count
print(f"Number of policies containing the keyword(s) {keywords}: {keyword_count}")

# Calculate the total number of 0s and 1s in the Energy Efficiency column
efficiency_counts = policies_with_keywords_in_text['Fleet Electrification'].value_counts()

# Display the total counts
print("\nTotal counts in the 'Fleet Electrification' column:")
print(efficiency_counts)

# Display which keywords were found and their counts
keyword_found_counts = {keyword: policies_with_keywords_in_text["BP3511: PDF Text"].apply(
    lambda text: str(text).lower().count(keyword)
).sum() for keyword in keywords}

print("\nKeyword occurrences:")
for keyword, count in keyword_found_counts.items():
    print(f"'{keyword}': {count}")

# Display the relevant rows
print(f"\nPolicies containing any of the words {keywords}:")
policies_with_keywords_in_text[['District Name', 'BP3511: PDF Text', 'Fleet Electrification']]
# Out:
# Number of policies containing the keyword(s) ['electric school buses', 'fleet electrification schools', 'school district EV fleet', 'electric school bus', 'electric vehicle']: 0
#
# Total counts in the 'Fleet Electrification' column:
# Series([], Name: count, dtype: int64)
#
# Keyword occurrences:
# 'electric school buses': 0
# 'fleet electrification schools': 0
# 'school district EV fleet': 0
# 'electric school bus': 0
# 'electric vehicle': 0
#
# Policies containing any of the words ['electric school buses', 'fleet electrification schools', 'school district EV fleet', 'electric school bus', 'electric vehicle']:
# Empty DataFrame
# Columns: [District Name, BP3511: PDF Text, Fleet Electrification]
# Index: []

# %% [markdown]
# ### EV Chargers for Parking (not fleet)

# %%
# Calculate the total number of 0s and 1s in the EV Chargers for Parking (not fleet) column
EV_chargers_counts = data['EV Chargers for Parking'].value_counts()

# Display the counts
print("Counts in the 'EV Chargers for Parking' column:")
print(EV_chargers_counts)
# Out:
# Counts in the 'EV Chargers for Parking' column:
# EV Chargers for Parking
# 0.0    500
# 1.0     72
# Name: count, dtype: int64

# %%
# List of keywords to filter for EV Chargers for Parking (not fleet) Indicator 
keywords = ['school EV charging stations', 'electric vehicle chargers schools', 'public EV charging school parking']

# Filter policies containing any of the keywords
policies_with_keywords_in_text = data[data["BP3511: PDF Text"].apply(
    lambda text: any(keyword in str(text).lower() for keyword in keywords)
)]

# Count the number of policies containing the keywords
keyword_count = len(policies_with_keywords_in_text)

# Display the count
print(f"Number of policies containing the keyword(s) {keywords}: {keyword_count}")

# Calculate the total number of 0s and 1s in the Energy Efficiency column
efficiency_counts = policies_with_keywords_in_text['EV Chargers for Parking'].value_counts()

# Display the total counts
print("\nTotal counts in the 'EV Chargers for Parking' column:")
print(efficiency_counts)

# Display which keywords were found and their counts
keyword_found_counts = {keyword: policies_with_keywords_in_text["BP3511: PDF Text"].apply(
    lambda text: str(text).lower().count(keyword)
).sum() for keyword in keywords}

print("\nKeyword occurrences:")
for keyword, count in keyword_found_counts.items():
    print(f"'{keyword}': {count}")

# Display the relevant rows
print(f"\nPolicies containing any of the words {keywords}:")
policies_with_keywords_in_text[['District Name', 'BP3511: PDF Text', 'EV Chargers for Parking']]
# Out:
# Number of policies containing the keyword(s) ['school EV charging stations', 'electric vehicle chargers schools', 'public EV charging school parking']: 0
#
# Total counts in the 'EV Chargers for Parking' column:
# Series([], Name: count, dtype: int64)
#
# Keyword occurrences:
# 'school EV charging stations': 0
# 'electric vehicle chargers schools': 0
# 'public EV charging school parking': 0
#
# Policies containing any of the words ['school EV charging stations', 'electric vehicle chargers schools', 'public EV charging school parking']:
# Empty DataFrame
# Columns: [District Name, BP3511: PDF Text, EV Chargers for Parking]
# Index: []

# %% [markdown]
# ### Water Conservation

# %%
# Calculate the total number of 0s and 1s in the Water Conservation column
water_conservation_counts = data['Water Conservation'].value_counts()

# Display the counts
print("Counts in the 'Water Conservation' column:")
print(water_conservation_counts)
# Out:
# Counts in the 'Water Conservation' column:
# Water Conservation
# 0    403
# 1    170
# Name: count, dtype: int64

# %%
# List of keywords to filter for Water Conservation Indicator 
# added water conservation, water efficiency, water-saving
keywords = ['water conservation in schools', 'school district water-saving', 'water efficiency educational institutions', 'water conservation', 'water efficiency', 'water-saving']

# Filter policies containing any of the keywords
policies_with_keywords_in_text = data[data["BP3511: PDF Text"].apply(
    lambda text: any(keyword in str(text).lower() for keyword in keywords)
)]

# Count the number of policies containing the keywords
keyword_count = len(policies_with_keywords_in_text)

# Display the count
print(f"Number of policies containing the keyword(s) {keywords}: {keyword_count}")

# Calculate the total number of 0s and 1s in the Energy Efficiency column
efficiency_counts = policies_with_keywords_in_text['Water Conservation'].value_counts()

# Display the total counts
print("\nTotal counts in the 'Water Conservation' column:")
print(efficiency_counts)

# Display which keywords were found and their counts
keyword_found_counts = {keyword: policies_with_keywords_in_text["BP3511: PDF Text"].apply(
    lambda text: str(text).lower().count(keyword)
).sum() for keyword in keywords}

print("\nKeyword occurrences:")
for keyword, count in keyword_found_counts.items():
    print(f"'{keyword}': {count}")

# Display the relevant rows
print(f"\nPolicies containing any of the words {keywords}:")
policies_with_keywords_in_text[['District Name', 'BP3511: PDF Text', 'Water Conservation']]
# Out:
# Number of policies containing the keyword(s) ['water conservation in schools', 'school district water-saving', 'water efficiency educational institutions', 'water conservation', 'water efficiency', 'water-saving']: 61
#
# Total counts in the 'Water Conservation' column:
# Water Conservation
# 0    39
# 1    22
# Name: count, dtype: int64
#
# Keyword occurrences:
# 'water conservation in schools': 0
# 'school district water-saving': 0
# 'water efficiency educational institutions': 0
# 'water conservation': 120
# 'water efficiency': 4
# 'water-saving': 0
#
# Policies containing any of the words ['water conservation in schools', 'school district water-saving', 'water efficiency educational institutions', 'water conservation', 'water efficiency', 'water-saving']:
#                  District Name  \
# 51              Clovis Unified
# 338                  Hollister
# 291          Santa Ana Unified
# 292  Saddleback Valley Unified
# 44   Gold Oak Union Elementary
# ..                         ...
# 553    Patterson Joint Unified
# 37           Pittsburg Unified
# 444  Buellton Union Elementary
# 205   Acton-Agua Dulce Unified
# 333    Sacramento City Unified
#
#                                       BP3511: PDF Text  Water Conservation
# 51   board policy 3511 clovis unified school distri...                   1
# 338  bp 3511 board policy business noninstructional...                   1
# 291  santa ana unified school district board policy...                   1
# 292  saddleback valley unified school district bp 3...                   0
# 44   business noninstructional operation bp 3511 en...                   0
# ..                                                 ...                 ...
# 553  policy 3511 energy water management status ado...                   0
# 37   policy 3511 energy water management status ado...                   1
# 444  policy 3511 energy water management status ado...                   0
# 205  policy 3511 energy water management status ado...                   0
# 333  policy 3511 energy water management status ado...                   1
#
# [61 rows x 3 columns]

# %% [markdown]
# ### Zero Waste Initiative

# %%
# Calculate the total number of 0s and 1s in the Zero Waste Initiative column
zero_waste_counts = data['Zero Waste Initiative'].value_counts()

# Display the counts
print("Counts in the 'Zero Waste Initiative' column:")
print(zero_waste_counts)
# Out:
# Counts in the 'Zero Waste Initiative' column:
# Zero Waste Initiative
# 0    449
# 1    124
# Name: count, dtype: int64

# %%
# List of keywords to filter for Zero Waste Initiative Indicator 
keywords = ['zero waste schools', 'waste reduction initiatives', 'school district recycling programs', 'recycling', 'waste reduction', 'zero waste']

# Filter policies containing any of the keywords
policies_with_keywords_in_text = data[data["BP3511: PDF Text"].apply(
    lambda text: any(keyword in str(text).lower() for keyword in keywords)
)]

# Count the number of policies containing the keywords
keyword_count = len(policies_with_keywords_in_text)

# Display the count
print(f"Number of policies containing the keyword(s) {keywords}: {keyword_count}")

# Calculate the total number of 0s and 1s in the Energy Efficiency column
efficiency_counts = policies_with_keywords_in_text['Zero Waste Initiative'].value_counts()

# Display the total counts
print("\nTotal counts in the 'Zero Waste Initiative' column:")
print(efficiency_counts)

# Display which keywords were found and their counts
keyword_found_counts = {keyword: policies_with_keywords_in_text["BP3511: PDF Text"].apply(
    lambda text: str(text).lower().count(keyword)
).sum() for keyword in keywords}

print("\nKeyword occurrences:")
for keyword, count in keyword_found_counts.items():
    print(f"'{keyword}': {count}")

# Display the relevant rows
print(f"\nPolicies containing any of the words {keywords}:")
policies_with_keywords_in_text[['District Name', 'BP3511: PDF Text', 'Zero Waste Initiative']]
# Out:
# Number of policies containing the keyword(s) ['zero waste schools', 'waste reduction initiatives', 'school district recycling programs', 'recycling', 'waste reduction', 'zero waste']: 194
#
# Total counts in the 'Zero Waste Initiative' column:
# Zero Waste Initiative
# 0    148
# 1     46
# Name: count, dtype: int64
#
# Keyword occurrences:
# 'zero waste schools': 0
# 'waste reduction initiatives': 0
# 'school district recycling programs': 0
# 'recycling': 197
# 'waste reduction': 3
# 'zero waste': 0
#
# Policies containing any of the words ['zero waste schools', 'waste reduction initiatives', 'school district recycling programs', 'recycling', 'waste reduction', 'zero waste']:
#                   District Name  \
# 151  Antelope Valley Union High
# 336             Natomas Unified
# 170          El Segundo Unified
# 566         Los Molinos Unified
# 357            Redlands Unified
# ..                          ...
# 57     Pacific Union Elementary
# 84     Pacific Union Elementary
# 99   San Pasqual Valley Unified
# 37            Pittsburg Unified
# 333     Sacramento City Unified
#
#                                       BP3511: PDF Text  Zero Waste Initiative
# 151  policy 3511 energy water management status ado...                      0
# 336  bp 3511 business noninstructional operation en...                      1
# 170  book board policy section 3000 business nonins...                      0
# 566  bp 3511 business noninstructional operation ma...                      0
# 357  policy 3511 energy water management status ado...                      0
# ..                                                 ...                    ...
# 57   policy 3511 energy water management status ado...                      1
# 84   policy 3511 energy water management status ado...                      1
# 99   policy 3511 energy water management status ado...                      0
# 37   policy 3511 energy water management status ado...                      0
# 333  policy 3511 energy water management status ado...                      1
#
# [194 rows x 3 columns]

# %% [markdown]
# ### Schoolyard Forest

# %%
# Calculate the total number of 0s and 1s in the Schoolyard Forest column
schoolyard_forest_counts = data['Schoolyard Forest'].value_counts()

# Display the counts
print("Counts in the 'Schoolyard Forest' column:")
print(schoolyard_forest_counts)
# Out:
# Counts in the 'Schoolyard Forest' column:
# Schoolyard Forest
# 0    538
# 1     35
# Name: count, dtype: int64

# %%
# List of keywords to filter for Schoolyard Forest Indicator 
keywords = ['schoolyard forest program', 'urban forestry schools', 'tree planting educational campus', 'forest', 'planting']
# Filter policies containing any of the keywords
policies_with_keywords_in_text = data[data["BP3511: PDF Text"].apply(
    lambda text: any(keyword in str(text).lower() for keyword in keywords)
)]

# Count the number of policies containing the keywords
keyword_count = len(policies_with_keywords_in_text)

# Display the count
print(f"Number of policies containing the keyword(s) {keywords}: {keyword_count}")

# Calculate the total number of 0s and 1s in the Energy Efficiency column
efficiency_counts = policies_with_keywords_in_text['Schoolyard Forest'].value_counts()

# Display the total counts
print("\nTotal counts in the 'Schoolyard Forest' column:")
print(efficiency_counts)

# Display which keywords were found and their counts
keyword_found_counts = {keyword: policies_with_keywords_in_text["BP3511: PDF Text"].apply(
    lambda text: str(text).lower().count(keyword)
).sum() for keyword in keywords}

print("\nKeyword occurrences:")
for keyword, count in keyword_found_counts.items():
    print(f"'{keyword}': {count}")

# Display the relevant rows
print(f"\nPolicies containing any of the words {keywords}:")
policies_with_keywords_in_text[['District Name', 'BP3511: PDF Text', 'Schoolyard Forest']]
# Out:
# Number of policies containing the keyword(s) ['schoolyard forest program', 'urban forestry schools', 'tree planting educational campus', 'forest', 'planting']: 1
#
# Total counts in the 'Schoolyard Forest' column:
# Schoolyard Forest
# 0    1
# Name: count, dtype: int64
#
# Keyword occurrences:
# 'schoolyard forest program': 0
# 'urban forestry schools': 0
# 'tree planting educational campus': 0
# 'forest': 1
# 'planting': 0
#
# Policies containing any of the words ['schoolyard forest program', 'urban forestry schools', 'tree planting educational campus', 'forest', 'planting']:
#                    District Name  \
# 298  Foresthill Union Elementary
#
#                                       BP3511: PDF Text  Schoolyard Forest
# 298  policy 3511 energy water management status ado...                  0

# %% [markdown]
# ### School Gardens

# %%
# Calculate the total number of 0s and 1s in the School Gardens column
school_gardens_counts = data['School Gardens'].value_counts()

# Display the counts
print("Counts in the 'School Gardens' column:")
print(school_gardens_counts)
# Out:
# Counts in the 'School Gardens' column:
# School Gardens
# 1    305
# 0    268
# Name: count, dtype: int64

# %%
# List of keywords to filter for School Gardens Indicator 
keywords = ['school garden projects', 'edible gardens in schools', 'educational gardens school district', 'interactive gardens', 'garden', 'native gardens', 'gardens']
# Filter policies
policies_with_keywords_in_text = data[data["BP3511: PDF Text"].apply(
    lambda text: any(keyword in str(text).lower() for keyword in keywords)
)]

# Count the number of policies containing the keywords
keyword_count = len(policies_with_keywords_in_text)

# Display the count
print(f"Number of policies containing the keyword(s) {keywords}: {keyword_count}")

# Calculate the total number of 0s and 1s in the Energy Efficiency column
efficiency_counts = policies_with_keywords_in_text['School Gardens'].value_counts()

# Display the total counts
print("\nTotal counts in the 'School Gardens' column:")
print(efficiency_counts)

# Display which keywords were found and their counts
keyword_found_counts = {keyword: policies_with_keywords_in_text["BP3511: PDF Text"].apply(
    lambda text: str(text).lower().count(keyword)
).sum() for keyword in keywords}

print("\nKeyword occurrences:")
for keyword, count in keyword_found_counts.items():
    print(f"'{keyword}': {count}")

# Display the relevant rows
print(f"\nPolicies containing any of the words {keywords}:")
policies_with_keywords_in_text[['District Name', 'BP3511: PDF Text', 'School Gardens']]
# Out:
# Number of policies containing the keyword(s) ['school garden projects', 'edible gardens in schools', 'educational gardens school district', 'interactive gardens', 'garden', 'native gardens', 'gardens']: 0
#
# Total counts in the 'School Gardens' column:
# Series([], Name: count, dtype: int64)
#
# Keyword occurrences:
# 'school garden projects': 0
# 'edible gardens in schools': 0
# 'educational gardens school district': 0
# 'interactive gardens': 0
# 'garden': 0
# 'native gardens': 0
# 'gardens': 0
#
# Policies containing any of the words ['school garden projects', 'edible gardens in schools', 'educational gardens school district', 'interactive gardens', 'garden', 'native gardens', 'gardens']:
# Empty DataFrame
# Columns: [District Name, BP3511: PDF Text, School Gardens]
# Index: []

# %% [markdown]
# ### Indicators Summary

# %%
# List of indicator columns 
indicator_columns = ['Building Electrification', 'Energy Efficiency', 'On-Site Renewables', 'HVAC: AC', 'Indoor Air Quality', 'Energy Resilience', 'Fleet Electrification', 'EV Chargers for Parking', 'Water Conservation', 'Zero Waste Initiative', 'Schoolyard Forest', 'School Gardens']  # Replace with your actual column names

# Calculate the counts of 1s and 0s for each indicator
indicator_summary = pd.DataFrame({
    'Indicator': indicator_columns,
    'Count_1s': [data[col].sum() for col in indicator_columns],  
    'Count_0s': [len(data[col]) - data[col].sum() for col in indicator_columns]  
})

# Display the summary table
print("Indicator Summary:\n", indicator_summary)

# Plot the results
plt.figure(figsize=(12, 6))

# Stacked bar chart for counts of 1s and 0s
plt.bar(indicator_summary['Indicator'], indicator_summary['Count_1s'], label='Count of 1s', color='skyblue', edgecolor='black')
plt.bar(indicator_summary['Indicator'], indicator_summary['Count_0s'], bottom=indicator_summary['Count_1s'], label='Count of 0s', color='lightcoral', edgecolor='black')

# Add labels and title
plt.xlabel('Indicators', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.title('Comparison of 1s and 0s Across Indicators', fontsize=14)
plt.legend()
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# Indicator Summary:
#                     Indicator  Count_1s  Count_0s
# 0   Building Electrification     220.0     353.0
# 1          Energy Efficiency     278.0     295.0
# 2         On-Site Renewables     238.0     335.0
# 3                   HVAC: AC     343.0     230.0
# 4         Indoor Air Quality     256.0     317.0
# 5          Energy Resilience     168.0     405.0
# 6      Fleet Electrification     102.0     471.0
# 7    EV Chargers for Parking      72.0     501.0
# 8         Water Conservation     170.0     403.0
# 9      Zero Waste Initiative     124.0     449.0
# 10         Schoolyard Forest      35.0     538.0
# 11            School Gardens     305.0     268.0

# %% [markdown]
# ### Scoville Scale Language Menu of Possible Revisions

# %%
# Mild, medium, spicy for Strategy 1 
# Text from the PDF 
mild_text = "The Superintendent or designee shall regularly inspect district facilities and operations and make recommendations for maintenance and capital expenditures which may help the district reach its conservation and management goals"
medium_text = "The Superintendent or designee shall regularly inspect district facilities and operations and develop and implement plans for maintenance and capital expenditures to achieve the district’s conservation and management goals"
spicy_text = "The Superintendent or designee shall inspect district facilities and operations on a [timeline] basis and develop and implement plans for maintenance and capital expenditures to achieve the district’s conservation and management goals, including but not limited to: Replacing machinery or HVAC systems with the most energy efficient options available Installing renewable energy upgrades or alternatives Determining and implementing the most water-conserving methods for facilities across the district Ensuring all new construction follows guidelines developed to achieve the district’s energy and water conservation goals"

commitment_texts = {
    'Mild': mild_text,
    'Medium': medium_text,
    'Spicy': spicy_text
}

# Define function 
def classify_policy(policy_text, commitment_texts):
    if not isinstance(policy_text, str) or not policy_text.strip():
        return None  
    
    # Combine the commitment texts and the policy text
    texts = list(commitment_texts.values()) + [policy_text]
    
    # Compute TF-IDF and cosine similarity
    vectorizer = TfidfVectorizer()
    tfidf_matrix = vectorizer.fit_transform(texts)
    similarities = cosine_similarity(tfidf_matrix[-1:], tfidf_matrix[:-1]).flatten()
    
    # Return the category with the highest similarity
    best_match = max(zip(commitment_texts.keys(), similarities), key=lambda x: x[1])
    return best_match

# Apply classification to each policy
data['Classification'] = data['BP3511: PDF Text'].apply(lambda x: classify_policy(x, commitment_texts))
# Split classification results into separate columns
data[['Assigned Level', 'Similarity Score']] = data['Classification'].apply(
    lambda x: pd.Series(x) if x else pd.Series([None, None])
)

# Display the classification results
data[['District Name', 'BP3511: PDF Text', 'Assigned Level', 'Similarity Score']]
# Out:
#                       District Name  \
# 293                  Tustin Unified
# 51                   Clovis Unified
# 259              Salinas Union High
# 338                       Hollister
# 291               Santa Ana Unified
# ..                              ...
# 430                        Pacifica
# 400              San Marcos Unified
# 333         Sacramento City Unified
# 83   McKinleyville Union Elementary
# 142              Middletown Unified
#
#                                       BP3511: PDF Text Assigned Level  \
# 293  book policy manual section 3000 business servi...         Medium
# 51   board policy 3511 clovis unified school distri...          Spicy
# 259  salina union high school district business pol...          Spicy
# 338  bp 3511 board policy business noninstructional...          Spicy
# 291  santa ana unified school district board policy...          Spicy
# ..                                                 ...            ...
# 430  policy 3511 energy water management status ado...           Mild
# 400  policy 3511 energy water management status ado...           Mild
# 333  policy 3511 energy water management status ado...          Spicy
# 83   policy 3511 energy water management status ado...           Mild
# 142  middletown unified school district policy 3511...          Spicy
#
#      Similarity Score
# 293          0.042996
# 51           0.278216
# 259          0.174673
# 338          0.192236
# 291          0.243863
# ..                ...
# 430          0.210545
# 400          0.210272
# 333          0.178084
# 83           0.206856
# 142          0.157189
#
# [573 rows x 4 columns]

# %%
# Count the number of policies in each classification level
classification_counts = data['Assigned Level'].value_counts()

# Bar chart of classification levels
plt.figure(figsize=(8, 6))
classification_counts.plot(kind='bar', color=['skyblue', 'red', 'orange'], edgecolor='black')
plt.xlabel('Commitment Level', fontsize=12)
plt.ylabel('Number of Policies', fontsize=12)
plt.title('Classification of Policies by Strategy 1: Energy and Water Conservation and Management', fontsize=14)
plt.tight_layout()
plt.show()

# %%
# Count the number of policies in each category
category_counts = data['Assigned Level'].value_counts()

# Display the counts
print("Number of Policies in Each Category:")
print(category_counts)
# Out:
# Number of Policies in Each Category:
# Assigned Level
# Mild      350
# Spicy     221
# Medium      2
# Name: count, dtype: int64

# %%
# Filter data for each commitment level
mild_policies = data[data['Assigned Level'] == 'Mild']
medium_policies = data[data['Assigned Level'] == 'Medium']
spicy_policies = data[data['Assigned Level'] == 'Spicy']

import matplotlib.pyplot as plt

# Function to plot commitment scores for a given level
def plot_commitment_scores(policies, level):
    plt.figure(figsize=(10, 6))
    plt.hist(policies['District-Wide Campus Sustainability Indicators (up to 3)'], bins=5, color='skyblue', edgecolor='black', alpha=0.7)
    plt.xlabel('Commitment Score', fontsize=12)
    plt.ylabel('Frequency', fontsize=12)
    plt.title(f'Commitment Scores for {level} Policies', fontsize=14)
    plt.grid(alpha=0.3)
    plt.tight_layout()
    plt.show()

# Plot for Mild policies
plot_commitment_scores(mild_policies, 'Mild')

# Plot for Medium policies
plot_commitment_scores(medium_policies, 'Medium')

# Plot for Spicy policies
plot_commitment_scores(spicy_policies, 'Spicy')

# %%
# Mild, medium, spicy for Strategy 2  
# Text from the PDF 
mild_text = "The Superintendent or designee shall make every effort to identify funding opportunities and cost-reducing incentive programs to help the district achieve its conservation and management goals. The Superintendent or designee shall periodically report to the Board on the district's  progress in meeting its conservation and management goals"
medium_text = "The Superintendent or designee shall identify funding opportunities and develop and implement cost-reducing incentive programs to help the district achieve its conservation and management goals. The Superintendent or designee shall periodically report to the Board on the district's progress in meeting its conservation and management goals"
spicy_text = "The Superintendent or designee shall allocate funding and develop and implement cost-reducing incentive programs to achieve the district’s conservation and  management goals, including K-12 student involvement via experiential learning and curricular participation. The Superintendent or designee shall report to the Board on a [timeline] basis on the district's progress in meeting its conservation and management goals"

commitment_texts = {
    'Mild': mild_text,
    'Medium': medium_text,
    'Spicy': spicy_text
}


# Define function
def classify_policy(policy_text, commitment_texts):
    if not isinstance(policy_text, str) or not policy_text.strip():
        return None 
    
    # Combine commitment texts and the policy text
    texts = list(commitment_texts.values()) + [policy_text]
    
    # Compute TF-IDF and cosine similarity
    vectorizer = TfidfVectorizer()
    tfidf_matrix = vectorizer.fit_transform(texts)
    similarities = cosine_similarity(tfidf_matrix[-1:], tfidf_matrix[:-1]).flatten()
    
    # Return category with the highest similarity
    best_match = max(zip(commitment_texts.keys(), similarities), key=lambda x: x[1])
    return best_match

# Apply classification to each policy
data['Classification'] = data['BP3511: PDF Text'].apply(lambda x: classify_policy(x, commitment_texts))
# Split classification results into separate columns
data[['Assigned Level', 'Similarity Score']] = data['Classification'].apply(
    lambda x: pd.Series(x) if x else pd.Series([None, None])
)

# Display classification results
data[['District Name', 'BP3511: PDF Text', 'Assigned Level', 'Similarity Score']]
# Out:
#                       District Name  \
# 293                  Tustin Unified
# 51                   Clovis Unified
# 259              Salinas Union High
# 338                       Hollister
# 291               Santa Ana Unified
# ..                              ...
# 430                        Pacifica
# 400              San Marcos Unified
# 333         Sacramento City Unified
# 83   McKinleyville Union Elementary
# 142              Middletown Unified
#
#                                       BP3511: PDF Text Assigned Level  \
# 293  book policy manual section 3000 business servi...          Spicy
# 51   board policy 3511 clovis unified school distri...           Mild
# 259  salina union high school district business pol...           Mild
# 338  bp 3511 board policy business noninstructional...           Mild
# 291  santa ana unified school district board policy...           Mild
# ..                                                 ...            ...
# 430  policy 3511 energy water management status ado...           Mild
# 400  policy 3511 energy water management status ado...           Mild
# 333  policy 3511 energy water management status ado...         Medium
# 83   policy 3511 energy water management status ado...           Mild
# 142  middletown unified school district policy 3511...           Mild
#
#      Similarity Score
# 293          0.039881
# 51           0.140826
# 259          0.138928
# 338          0.180307
# 291          0.178575
# ..                ...
# 430          0.218791
# 400          0.218522
# 333          0.145784
# 83           0.216337
# 142          0.147588
#
# [573 rows x 4 columns]

# %%
# Count the number of policies in each classification level
classification_counts = data['Assigned Level'].value_counts()

# Bar chart of classification levels
plt.figure(figsize=(8, 6))
classification_counts.plot(kind='bar', color=['skyblue', 'orange', 'red'], edgecolor='black')
plt.xlabel('Commitment Level', fontsize=12)
plt.ylabel('Number of Policies', fontsize=12)
plt.title('Classification of Policies by Strategy 2: Identifying and Investing in Water and Energy Programs and Opportunities', fontsize=14)
plt.tight_layout()
plt.show()

# %%
# Count the number of policies in each category
category_counts = data['Assigned Level'].value_counts()

# Display counts
print("Number of Policies in Each Category:")
print(category_counts)
# Out:
# Number of Policies in Each Category:
# Assigned Level
# Mild      557
# Medium      9
# Spicy       7
# Name: count, dtype: int64

# %%
# Filter data for each commitment level
mild_policies = data[data['Assigned Level'] == 'Mild']
medium_policies = data[data['Assigned Level'] == 'Medium']
spicy_policies = data[data['Assigned Level'] == 'Spicy']


# Function to plot commitment scores 
def plot_commitment_scores(policies, level):
    plt.figure(figsize=(10, 6))
    plt.hist(policies['District-Wide Campus Sustainability Indicators (up to 3)'], bins=5, color='skyblue', edgecolor='black', alpha=0.7)
    plt.xlabel('Commitment Score', fontsize=12)
    plt.ylabel('Frequency', fontsize=12)
    plt.title(f'Commitment Scores for {level} Policies', fontsize=14)
    plt.grid(alpha=0.3)
    plt.tight_layout()
    plt.show()

# Plot for Mild policies
plot_commitment_scores(mild_policies, 'Mild')

# Plot for Medium policies
plot_commitment_scores(medium_policies, 'Medium')

# Plot for Spicy policies
plot_commitment_scores(spicy_policies, 'Spicy')

# %%
# Mild, medium, spicy for Strategy 3
# Text from the PDF 
mild_text = "The Board desires to ensure that, to the maximum extent practicable, the district reduces the discharge of pollutants into the water system in order to minimize the threat to water quality from stormwater runoff. When the district has been designated by the State Water  Resources Control Board or a regional water quality control board, the Superintendent or  designee shall ensure that the district complies with applicable General Permit requirements"
medium_text = "The Board desires to ensure that the district will not discharge pollutants into the water system in order to minimize the threat to water quality from stormwater runoff. When the district has been designated by the State Water Resources Control Board or a regional water quality control board, the Superintendent or designee shall ensure that the district complies with applicable General Permit requirements"
spicy_text = "The Board ensures that the district will not discharge pollutants into the water system in order to eliminate the threat to water quality from stormwater runoff. In this case, “discharge” is defined as accidental or purposeful release of contaminants or pollutants into the water system by the district, staff, faculty, students, facilities, or operations associated with the district. The Superintendent or designee shall ensure that the district complies with applicable General Permit requirements, as well as all regulations from the State Water Resources Control Board or a regional water quality control board"

commitment_texts = {
    'Mild': mild_text,
    'Medium': medium_text,
    'Spicy': spicy_text
}

# Define a function 
def classify_policy(policy_text, commitment_texts):
    if not isinstance(policy_text, str) or not policy_text.strip():
        return None 
    
    # Combine the commitment texts and the policy text
    texts = list(commitment_texts.values()) + [policy_text]
    
    # Compute TF-IDF and cosine similarity
    vectorizer = TfidfVectorizer()
    tfidf_matrix = vectorizer.fit_transform(texts)
    similarities = cosine_similarity(tfidf_matrix[-1:], tfidf_matrix[:-1]).flatten()
    
    # Return the category with the highest similarity
    best_match = max(zip(commitment_texts.keys(), similarities), key=lambda x: x[1])
    return best_match

# Apply classification to each policy
data['Classification'] = data['BP3511: PDF Text'].apply(lambda x: classify_policy(x, commitment_texts))
# Split classification results into separate columns
data[['Assigned Level', 'Similarity Score']] = data['Classification'].apply(
    lambda x: pd.Series(x) if x else pd.Series([None, None])
)

# Display classification results
data[['District Name', 'BP3511: PDF Text', 'Assigned Level', 'Similarity Score']]
# Out:
#                       District Name  \
# 293                  Tustin Unified
# 51                   Clovis Unified
# 259              Salinas Union High
# 338                       Hollister
# 291               Santa Ana Unified
# ..                              ...
# 430                        Pacifica
# 400              San Marcos Unified
# 333         Sacramento City Unified
# 83   McKinleyville Union Elementary
# 142              Middletown Unified
#
#                                       BP3511: PDF Text Assigned Level  \
# 293  book policy manual section 3000 business servi...          Spicy
# 51   board policy 3511 clovis unified school distri...         Medium
# 259  salina union high school district business pol...         Medium
# 338  bp 3511 board policy business noninstructional...         Medium
# 291  santa ana unified school district board policy...         Medium
# ..                                                 ...            ...
# 430  policy 3511 energy water management status ado...         Medium
# 400  policy 3511 energy water management status ado...         Medium
# 333  policy 3511 energy water management status ado...         Medium
# 83   policy 3511 energy water management status ado...         Medium
# 142  middletown unified school district policy 3511...         Medium
#
#      Similarity Score
# 293          0.023699
# 51           0.187992
# 259          0.156634
# 338          0.180944
# 291          0.127607
# ..                ...
# 430          0.194316
# 400          0.194072
# 333          0.089417
# 83           0.191139
# 142          0.154905
#
# [573 rows x 4 columns]

# %%
# Count the number of policies in each classification level
classification_counts = data['Assigned Level'].value_counts()

# Bar chart of classification levels
plt.figure(figsize=(8, 6))
classification_counts.plot(kind='bar', color=['orange', 'red'], edgecolor='black')
plt.xlabel('Commitment Level', fontsize=12)
plt.ylabel('Number of Policies', fontsize=12)
plt.title('Classification of Policies by Strategy 3: Stormwater Management General Permit Compliance', fontsize=14)
plt.tight_layout()
plt.show()

# %%
# Count the number of policies in each category
category_counts = data['Assigned Level'].value_counts()

# Display the counts
print("Number of Policies in Each Category:")
print(category_counts)
# Out:
# Number of Policies in Each Category:
# Assigned Level
# Medium    571
# Spicy       2
# Name: count, dtype: int64

# %%
# Filter data for each commitment level
mild_policies = data[data['Assigned Level'] == 'Mild']
medium_policies = data[data['Assigned Level'] == 'Medium']
spicy_policies = data[data['Assigned Level'] == 'Spicy']


# Function to plot commitment scores for a given level
def plot_commitment_scores(policies, level):
    plt.figure(figsize=(10, 6))
    plt.hist(policies['District-Wide Campus Sustainability Indicators (up to 3)'], bins=5, color='skyblue', edgecolor='black', alpha=0.7)
    plt.xlabel('Commitment Score', fontsize=12)
    plt.ylabel('Frequency', fontsize=12)
    plt.title(f'Commitment Scores for {level} Policies', fontsize=14)
    plt.grid(alpha=0.3)
    plt.tight_layout()
    plt.show()

# Plot for Mild policies
plot_commitment_scores(mild_policies, 'Mild')

# Plot for Medium policies
plot_commitment_scores(medium_policies, 'Medium')

# Plot for Spicy policies
plot_commitment_scores(spicy_policies, 'Spicy')

# %%
# Mild, medium, spicy for Strategy 4
# Text from the PDF 
mild_text = "The district's plan shall describe best management practices, measurable goals, and  timetables for implementation in the following areas: Public education and outreach on stormwater impacts Public participation, such as participation in adoption and implementation of the plan Illicit discharge detection and elimination, such as maps and programs to detect and  eliminate illicit non-storm water discharges Construction site stormwater runoff control, such as reviewing construction plans,  inspecting sites, and tracking construction site runoff, as well as erosion and sediment  control Post-construction stormwater management, such as developing design standards for  preventing runoff and verifying proper maintenance and operation of control  procedures  Pollution prevention and good housekeeping, such as evaluating waste disposal, material storage, and equipment-cleaning procedures and spill prevention, including  at bus maintenance facilities"
medium_text = "The district's plan shall develop best management practices, measurable goals, and  timetables for implementation in the following areas: Public education and outreach on stormwater impacts, stormwater reduction methods, and pollution reduction methods and importance Public participation, such as participation in adoption and implementation of the plan Illicit discharge detection and elimination, such as maps and programs to detect and eliminate illicit non-storm water discharges Construction site stormwater runoff control, such as reviewing construction plans, inspecting sites, and tracking and eliminating construction site runoff, as well as erosion and sediment control Post-construction stormwater management, such as developing and implementing design standards for preventing runoff and verifying proper maintenance and operation of control procedures  Pollution prevention and good housekeeping, such as evaluating waste disposal, material storage, equipment-cleaning procedures, pesticide use, and spill prevention, including at bus maintenance facilities"
spicy_text = "The district's plan shall develop best management practices, measurable goals, and  timetables for implementation in the following areas: Public education and outreach, including K-12 experiential learning and curricular resources, on stormwater impacts, stormwater reduction methods, and pollution reduction methods and importance, such as building rain gardens or not spraying pesticides when it is projected to rain. Public participation, including K-12 experiential learning and classroom participation and provide publicly-available data that tracks energy and water use, as well as other key measures, in a form that is accessible to students and the community. Illicit discharge detection and elimination, such as maps and programs to detect and eliminate illicit non-storm water discharges as well as significant fines and other deterrents to prevent illicit non-stormwater discharges. Construction site stormwater runoff control, such as reviewing construction plans for possible water runoff contamination hazards, inspecting sites for current or future water runoff contamination, and tracking and eliminating construction site runoff, as well as erosion and sediment control Post-construction stormwater management, such as developing and implementing design standards for  preventing runoff and verifying proper maintenance and operation of control procedures  Pollution prevention and good housekeeping, such as evaluating waste disposal, material storage, equipment-cleaning procedures, pesticide use, and spill prevention, including at bus maintenance facilities"


commitment_texts = {
    'Mild': mild_text,
    'Medium': medium_text,
    'Spicy': spicy_text
}


# Define function 
def classify_policy(policy_text, commitment_texts):
    if not isinstance(policy_text, str) or not policy_text.strip():
        return None 
    
    # Combine the commitment texts and the policy text
    texts = list(commitment_texts.values()) + [policy_text]
    
    # Compute TF-IDF and cosine similarity
    vectorizer = TfidfVectorizer()
    tfidf_matrix = vectorizer.fit_transform(texts)
    similarities = cosine_similarity(tfidf_matrix[-1:], tfidf_matrix[:-1]).flatten()
    
    # Return the category with the highest similarity
    best_match = max(zip(commitment_texts.keys(), similarities), key=lambda x: x[1])
    return best_match

# Apply classification to each policy
data['Classification'] = data['BP3511: PDF Text'].apply(lambda x: classify_policy(x, commitment_texts))
# Split classification results into separate columns
data[['Assigned Level', 'Similarity Score']] = data['Classification'].apply(
    lambda x: pd.Series(x) if x else pd.Series([None, None])
)

# Display classification results
data[['District Name', 'BP3511: PDF Text', 'Assigned Level', 'Similarity Score']]
# Out:
#                       District Name  \
# 293                  Tustin Unified
# 51                   Clovis Unified
# 259              Salinas Union High
# 338                       Hollister
# 291               Santa Ana Unified
# ..                              ...
# 430                        Pacifica
# 400              San Marcos Unified
# 333         Sacramento City Unified
# 83   McKinleyville Union Elementary
# 142              Middletown Unified
#
#                                       BP3511: PDF Text Assigned Level  \
# 293  book policy manual section 3000 business servi...           Mild
# 51   board policy 3511 clovis unified school distri...          Spicy
# 259  salina union high school district business pol...          Spicy
# 338  bp 3511 board policy business noninstructional...          Spicy
# 291  santa ana unified school district board policy...          Spicy
# ..                                                 ...            ...
# 430  policy 3511 energy water management status ado...          Spicy
# 400  policy 3511 energy water management status ado...          Spicy
# 333  policy 3511 energy water management status ado...          Spicy
# 83   policy 3511 energy water management status ado...          Spicy
# 142  middletown unified school district policy 3511...           Mild
#
#      Similarity Score
# 293          0.031629
# 51           0.098317
# 259          0.077218
# 338          0.076049
# 291          0.061073
# ..                ...
# 430          0.074551
# 400          0.074461
# 333          0.053740
# 83           0.074318
# 142          0.086491
#
# [573 rows x 4 columns]

# %%
# Count number of policies in each classification level
classification_counts = data['Assigned Level'].value_counts()

# Bar chart of classification levels
plt.figure(figsize=(8, 6))
classification_counts.plot(kind='bar', color=['red', 'skyblue', 'orange'], edgecolor='black')
plt.xlabel('Commitment Level', fontsize=12)
plt.ylabel('Number of Policies', fontsize=12)
plt.title('Classification of Policies by Strategy 4: Stormwater Management Plan', fontsize=14)
plt.tight_layout()
plt.show()

# %%
# Count number of policies in each category
category_counts = data['Assigned Level'].value_counts()

# Display the counts
print("Number of Policies in Each Category:")
print(category_counts)
# Out:
# Number of Policies in Each Category:
# Assigned Level
# Spicy     429
# Mild      124
# Medium     20
# Name: count, dtype: int64

# %%
# Filter data for each commitment level
mild_policies = data[data['Assigned Level'] == 'Mild']
medium_policies = data[data['Assigned Level'] == 'Medium']
spicy_policies = data[data['Assigned Level'] == 'Spicy']

# Function to plot commitment scores for a given level
def plot_commitment_scores(policies, level):
    plt.figure(figsize=(10, 6))
    plt.hist(policies['District-Wide Campus Sustainability Indicators (up to 3)'], bins=5, color='skyblue', edgecolor='black', alpha=0.7)
    plt.xlabel('Commitment Score', fontsize=12)
    plt.ylabel('Frequency', fontsize=12)
    plt.title(f'Commitment Scores for {level} Policies', fontsize=14)
    plt.grid(alpha=0.3)
    plt.tight_layout()
    plt.show()

# Plot for Mild policies
plot_commitment_scores(mild_policies, 'Mild')

# Plot for Medium policies
plot_commitment_scores(medium_policies, 'Medium')

# Plot for Spicy policies
plot_commitment_scores(spicy_policies, 'Spicy')
